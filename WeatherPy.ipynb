# %%
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint
import pprint 
from config1 import w_key
from citipy import citipy

# %% [markdown]
# *We need a list of cities to gather weather data. We will now generate a list of cities and then create a dataframe of the cities, and also export the cities to a CSV file.*

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
duplicated = []
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)
# Identify nearest city for each lat, lng combination
i = 1
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
   # print(f"record {i}", {lat_lng[0], lat_lng[1]}, {city})
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
    else:
        duplicated.append(city)
    i = i+1
print('\n')
print(f"Duplicated cities = {duplicated}")
print('\n')
# Print the city count to confirm sufficient count
print('\n')
print(f"Cities that will be used for analysis = {cities}")
print('\n')
print(f" Leaving behind the duplicated cities, the count of cities =  {len(cities)}")
# Out:
# Duplicated cities = ['bethel', 'ushuaia', 'lagoa', 'punta arenas', 'ushuaia', 'punta arenas', 'bethel', 'lebu', 'ushuaia', 'punta arenas', 'albany', 'albany', 'ushuaia', 'punta arenas', 'albany', 'bethel', 'jamestown', 'rikitea', 'ushuaia', 'busselton', 'hilo', 'rikitea', 'busselton', 'atuona', 'cidreira', 'rikitea', 'lebu', 'albany', 'puerto ayora', 'kapaa', 'ushuaia', 'busselton', 'kavieng', 'jamestown', 'kapaa', 'dikson', 'mar del plata', 'mataura', 'busselton', 'atuona', 'barentsburg', 'rikitea', 'ushuaia', 'hilo', 'port alfred', 'lebu', 'taolanaro', 'atuona', 'punta arenas', 'tuktoyaktuk', 'avarua', 'hilo', 'lebu', 'hermanus', 'georgetown', 'castro', 'muros', 'dikson', 'barrow', 'busselton', 'vaini', 'hermanus', 'puerto ayora', 'illoqqortoormiut', 'albany', 'ushuaia', 'avarua', 'yellowknife', 'mataura', 'cape town', 'yellowknife', 'castro', 'saleaula', 'clyde river', 'qaanaaq', 'vaini', 'ushuaia', 'rikitea', 'avarua', 'lavrentiya', 'hermanus', 'rikitea', 'taolanaro', 'georgetown', 'kapaa', 'punta arenas', 'rikitea', 'busselton', 'atuona', 'hermanus', 'khatanga', 'illoqqortoormiut', 'butaritari', 'tongliao', 'arraial do cabo', 'carnarvon', 'hermanus', 'busselton', 'ostrovnoy', 'mataura', 'qaanaaq', 'jamestown', 'bredasdorp', 'punta arenas', 'busselton', 'jamestown', 'carnarvon', 'new norfolk', 'albany', 'cape town', 'hermanus', 'hilo', 'albany', 'los llanos de aridane', 'qaanaaq', 'ambilobe', 'albany', 'georgetown', 'atuona', 'mataura', 'new norfolk', 'albany', 'carnarvon', 'bredasdorp', 'cidreira', 'albany', 'saskylakh', 'saint-philippe', 'new norfolk', 'avarua', 'punta arenas', 'bambous virieux', 'saint-philippe', 'kapaa', 'khatanga', 'albany', 'pisco', 'hermanus', 'saint george', 'atuona', 'beringovskiy', 'vaini', 'belushya guba', 'arraial do cabo', 'bluff', 'jamestown', 'rikitea', 'khatanga', 'albany', 'rikitea', 'cape town', 'kapaa', 'taolanaro', 'guerrero negro', 'busselton', 'mataura', 'ribeira grande', 'hobart', 'albany', 'rikitea', 'tuktoyaktuk', 'saleaula', 'arraial do cabo', 'cape town', 'hobart', 'pisco', 'yulara', 'bluff', 'georgetown', 'avarua', 'busselton', 'ushuaia', 'hithadhoo', 'cape town', 'east london', 'illoqqortoormiut', 'cidreira', 'albany', 'victoria', 'mar del plata', 'albany', 'ushuaia', 'punta arenas', 'yellowknife', 'punta arenas', 'atuona', 'rikitea', 'hithadhoo', 'provideniya', 'rikitea', 'cape town', 'khatanga', 'ushuaia', 'vaini', 'mataura', 'new norfolk', 'kapaa', 'kapaa', 'rikitea', 'vaini', 'carnarvon', 'kavieng', 'rikitea', 'tuktoyaktuk', 'punta arenas', 'dikson', 'flinders', 'vaitupu', 'tasiilaq', 'te anau', 'albany', 'lavrentiya', 'new norfolk', 'illoqqortoormiut', 'saleaula', 'punta arenas', 'jamestown', 'cidreira', 'albany', 'hobart', 'port lincoln', 'busselton', 'mataura', 'bredasdorp', 'dikson', 'atuona', 'avarua', 'bengkulu', 'albany', 'rikitea', 'mataura', 'kaitangata', 'hermanus', 'bredasdorp', 'chuy', 'beringovskiy', 'tasiilaq', 'bluff', 'east london', 'tasiilaq', 'cherskiy', 'avarua', 'saint-philippe', 'new norfolk', 'hithadhoo', 'nikolskoye', 'ushuaia', 'salalah', 'busselton', 'arraial do cabo', 'qaanaaq', 'cape town', 'cape town', 'mataura', 'port alfred', 'busselton', 'mogadishu', 'cabo san lucas', 'castro', 'hermanus', 'yulara', 'taolanaro', 'rikitea', 'kapaa', 'taolanaro', 'rikitea', 'atuona', 'bluff', 'hermanus', 'klaksvik', 'kudahuvadhoo', 'bluff', 'taolanaro', 'carnarvon', 'torbay', 'miri', 'la ronge', 'atuona', 'chokurdakh', 'provideniya', 'khatanga', 'rikitea', 'ushuaia', 'thompson', 'east london', 'albany', 'mataura', 'taolanaro', 'los llanos de aridane', 'hobart', 'taolanaro', 'kahului', 'taolanaro', 'bluff', 'rikitea', 'bluff', 'mataura', 'rikitea', 'lagoa', 'vaitupu', 'busselton', 'port elizabeth', 'yellowknife', 'ushuaia', 'mataura', 'mataura', 'illoqqortoormiut', 'tasiilaq', 'carnarvon', 'fortuna', 'hithadhoo', 'rikitea', 'bengkulu', 'mataura', 'ushuaia', 'arraial do cabo', 'puerto ayora', 'rikitea', 'taolanaro', 'busselton', 'rikitea', 'hofn', 'mar del plata', ...
#
#
#
#
# Cities that will be used for analysis = ['purranque', 'mount gambier', 'aksarka', 'huazolotitlan', 'rochegda', 'bambous virieux', 'bredasdorp', 'jamestown', 'ushuaia', 'castro', 'tigil', 'bethel', 'saleaula', 'ardakan', 'lebu', 'hilo', 'lhuntshi', 'parauna', 'atuona', 'dikson', 'vao', 'kalga', 'los andes', 'chokurdakh', 'cape town', 'nanortalik', 'punta arenas', 'gafanha da encarnacao', 'roros', 'illoqqortoormiut', 'lagoa', 'chitipa', 'gander', 'busselton', 'oksfjord', 'thayetmyo', 'beringovskiy', 'puerto ayora', 'yate', 'hithadhoo', 'butaritari', 'port lincoln', 'kavieng', 'hobart', 'evensk', 'yulara', 'lavrentiya', 'kiboga', 'mantua', 'tuktoyaktuk', 'albany', 'grand river south east', 'saskylakh', 'cherskiy', 'rikitea', 'sola', 'nouakchott', 'georgetown', 'saint george', 'avarua', 'ribeira grande', 'port-gentil', 'lompoc', 'vaitupu', 'cidreira', 'khatanga', 'flinders', 'taolanaro', 'yenagoa', 'tongliao', 'lasa', 'saint-philippe', 'manga', 'astoria', 'torbay', 'kapaa', 'bairiki', 'druzhba', 'nikolskoye', 'damavand', 'clyde river', 'plomarion', 'yavoriv', 'port elizabeth', 'belushya guba', 'roald', 'port alfred', 'salalah', 'miri', 'petropavlovsk-kamchatskiy', 'ambon', 'lazaro cardenas', 'aleksandrow kujawski', 'mopti', 'kahului', 'bengkulu', 'tokmak', 'teya', 'barentsburg', 'srednekolymsk', 'veraval', 'vaini', 'pasighat', 'ambilobe', 'mataura', 'alice springs', 'olafsvik', 'la victoria', 'tessalit', 'barrow', 'anqing', 'oktyabrskiy', 'arraial do cabo', 'kusk', 'mar del plata', 'severo-kurilsk', 'the valley', 'bluff', 'pemangkat', 'hervey bay', 'east london', 'airai', 'nouadhibou', 'sao filipe', 'luebo', 'rocha', 'arkhangelos', 'hermanus', 'young', 'sabzevar', 'cabo san lucas', 'pitimbu', 'tumen', 'wagar', 'thompson', 'broome', 'kruisfontein', 'kloulklubed', 'gilgit', 'ust-nera', 'victoria', 'okulovka', 'provideniya', 'cooma', 'yellowknife', 'klaksvik', 'wanaka', 'los llanos de aridane', 'hasaki', 'shingu', 'sao felix do xingu', 'muros', 'te anau', 'riyadh', 'tostamaa', 'tingo maria', 'kawalu', 'karratha', 'tumannyy', 'maniitsoq', 'ostrovnoy', 'magui', 'tautira', 'qaanaaq', 'susanville', 'poum', 'kjollefjord', 'carnarvon', 'lao cai', 'ilulissat', 'labuhan', 'den helder', 'zhigansk', 'saint anthony', 'alofi', 'guerrero negro', 'hofn', 'zhaoyuan', 'ust-barguzin', 'altamont', 'yingcheng', 'dodoma', 'mitu', 'ndjole', 'kaspiysk', 'valparaiso', 'labrea', 'antalaha', 'narsaq', 'plettenberg bay', 'kismayo', 'kudahuvadhoo', 'tungkang', 'camacha', 'isangel', 'alice', 'new norfolk', 'laguna', 'vanimo', 'svetlyy', 'kalghatgi', 'williamsport', 'sinnamary', 'beloha', 'tshela', 'tasiilaq', 'saint-joseph', 'maldonado', 'palabuhanratu', 'attawapiskat', 'pisco', 'tsihombe', 'xichang', 'landeck', 'samana', 'la libertad', 'cedar city', 'gunnedah', 'comodoro rivadavia', 'wanning', 'chokwe', 'kununurra', 'ajdabiya', 'richards bay', 'mecca', 'price', 'nguiu', 'allonnes', 'liberal', 'natchez', 'port blair', 'filadelfia', 'rio gallegos', 'mizan teferi', 'unai', 'tukrah', 'itarema', 'nabire', 'cabo rojo', 'ipixuna', 'vojens', 'tofield', 'mogadishu', 'paranhos', 'ouango', 'san patricio', 'morro bay', 'zakamensk', 'vilyuysk', 'obo', 'talnakh', 'tazovskiy', 'rosamorada', 'caravelas', 'maine-soroa', 'roma', 'longyearbyen', 'codrington', 'murdochville', 'maceio', 'chara', 'aylesbury', 'fortuna', 'nyurba', 'swan river', 'chuy', 'kaitangata', 'san francisco', 'homer', 'victor harbor', 'broken hill', 'haapiti', 'mehamn', 'lancaster', 'lorengau', 'saldanha', 'ondangwa', 'rundu', 'namtsy', 'hirara', 'kedrovyy', 'pajan', 'artyk', 'mersing', 'monterey', 'asau', 'jalu', 'harlingen', 'sitka', 'lahaina', 'loandjili', 'la ronge', 'henties bay', 'takoradi', 'boyolangu', 'andenes', 'faya', 'ayagoz', 'umm bab', 'terme', 'thinadhoo', 'chapais', 'ketchikan', 'pilao arcado', 'andapa', 'yerkoy', 'nola', 'wamba', 'kirakira', 'alugan', 'niquero', 'tynda', 'ono', 'conde', 'voznesenye', 'charters towers', 'peruibe', 'tiksi', 'mnichovo hradiste', 'bilibino', 'jiwani', 'moron', 'k ...
#
#
#  Leaving behind the duplicated cities, the count of cities =  626

# %% [markdown]
# *Creating a Dataframe of the generated Cities:*

# %%
cities_df = pd.DataFrame({'Cities' : cities})
cities_df.head()
# Out:
#           Cities
# 0      purranque
# 1  mount gambier
# 2        aksarka
# 3  huazolotitlan
# 4       rochegda

# %% [markdown]
# *Writing cities to csv:*

# %%
cities_df.to_csv(r"Cities.csv", index=False, header=True)
print("File write successful")
# Out:
# File write successful

# %% [markdown]
# *Defining the required functions to update metrics*

# %%
def kelvin_to_farenheit(temps):
    """Converts a Kelvin temperature to Fahrenheit"""
    return temps * 9/5 - 459.67

def mps_to_mph(windSpeed):
    """Converts a meters/s speed to miles/hour"""
    return windSpeed * 2.23694

# %% [markdown]
# *Performing API Calls using each city in the openweather API url get the weather data*

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?q="
#Obtain weathercheck data for the cities from openweather map: 

city_name = cities
row = []
city_row = []
for i in range(len(city_name)):
#for i in range(10):
    print(f"Processing request for index number: {i} which is for City: {city_name[i]}")
    url = base_url + city_name[i] + "&appid=" + w_key
    print(url)
    response = requests.get(url)
    city_json = response.json()
    #print(city_json)
    print(response.status_code)
    if response.status_code == 200:
        try:
            city_cntry = (city_json['sys']['country'])
            #print(city_cntry)
            city_lat = (city_json['coord']['lat'])
            #print(city_lat)
            city_lon = (city_json['coord']['lon']) 
           # print(city_lon)
            city_temp = kelvin_to_farenheit(city_json['main']['temp'])
           # print(city_temp)
            city_humidity = (city_json['main']['humidity'])
            #print(city_humidity)
            city_cloudiness = (city_json['clouds']['all'])
           # print(city_cloudiness)
            city_windSpeed = mps_to_mph(city_json['wind']['speed'])
           # print(city_windSpeed)
            row = [city_name[i], city_cntry, city_lat, city_lon, city_temp, city_humidity, city_cloudiness, city_windSpeed]
           # print(row)
            city_row.append(row)
            #print(city_row)
        except:
            print(f"I skipped {cities[i]} because something isn't right")

city_df = pd.DataFrame(city_row)   
city_df.columns = ['City', 'Country', 'Lat', 'Lon', 'Temp', 'Humidity', 'Cloudiness', 'Windspeed']

city_df.head()
# Out:
# Processing request for index number: 0 which is for City: purranque
# http://api.openweathermap.org/data/2.5/weather?q=purranque&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 1 which is for City: mount gambier
# http://api.openweathermap.org/data/2.5/weather?q=mount gambier&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 2 which is for City: aksarka
# http://api.openweathermap.org/data/2.5/weather?q=aksarka&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 3 which is for City: huazolotitlan
# http://api.openweathermap.org/data/2.5/weather?q=huazolotitlan&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 4 which is for City: rochegda
# http://api.openweathermap.org/data/2.5/weather?q=rochegda&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 5 which is for City: bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 6 which is for City: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 7 which is for City: jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 8 which is for City: ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 9 which is for City: castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 10 which is for City: tigil
# http://api.openweathermap.org/data/2.5/weather?q=tigil&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 11 which is for City: bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 12 which is for City: saleaula
# http://api.openweathermap.org/data/2.5/weather?q=saleaula&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 13 which is for City: ardakan
# http://api.openweathermap.org/data/2.5/weather?q=ardakan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 14 which is for City: lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 15 which is for City: hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 16 which is for City: lhuntshi
# http://api.openweathermap.org/data/2.5/weather?q=lhuntshi&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 17 which is for City: parauna
# http://api.openweathermap.org/data/2.5/weather?q=parauna&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 18 which is for City: atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 19 which is for City: dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 20 which is for City: vao
# http://api.openweathermap.org/data/2.5/weather?q=vao&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 21 which is for City: kalga
# http://api.openweathermap.org/data/2.5/weather?q=kalga&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 22 which is for City: los andes
# http://api.openweathermap.org/data/2.5/weather?q=los andes&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 23 which is for City: chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 24 which is for City: cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 25 which is for City: nanortalik
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 26 which is for City: punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 27 which is for City: gafanha da encarnacao
# http://api.openweathermap.org/data/2.5/weather?q=gafanha da encarnacao&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 28 which is for City: roros
# http://api.openweathermap.org/data/2.5/weather?q=roros&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 29 which is for City: illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 30 which is for City: lagoa
# http://api.openweathermap.org/data/2.5/weather?q=lagoa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 31 which is for City: chitipa
# http://api.openweathermap.org/data/2.5/weather?q=chitipa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 32 which is for City: gander
# http://api.openweathermap.org/data/2.5/weather?q=gander&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 33 which is for City: busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 34 which is for City: oksfjord
# http://api.openweathermap.org/data/2.5/weather?q=oksfjord&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 35 which is for City: thayetmyo
# http://api.openweathermap.org/data/2.5/weather?q=thayetmyo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 36 which is for City: beringovskiy
# http://api.openweathermap.org/data/2.5/weather?q=beringovskiy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 37 which is for City: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 38 which is for City: yate
# http://api.openweathermap.org/data/2.5/weather?q=yate&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 39 which is for City: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 40 which is for City: butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 41 which is for City: port lincoln
# http://api.openweathermap.org/data/2.5/weather?q=port lincoln&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 42 which is for City: kavieng
# http://api.openweathermap.org/data/2.5/weather?q=kavieng&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 43 which is for City: hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 44 which is for City: evensk
# http://api.openweathermap.org/data/2.5/weather?q=evensk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 45 which is for City: yulara
# http://api.openweathermap.org/data/2.5/weather?q=yulara&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 46 which is for City: lavrentiya
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 47 which is for City: kiboga
# http://api.openweathermap.org/data/2.5/weather?q=kiboga&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 48 which is for City: mantua
# http://api.openweathermap.org/data/2.5/weather?q=mantua&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 49 which is for City: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 50 which is for City: albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 51 which is for City: grand river south east
# http://api.openweathermap.org/data/2.5/weather?q=grand river south east&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 52 which is for City: saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 53 which is for City: cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 54 which is for City: rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 55 which is for City: sola
# http://api.openweathermap.org/data/2.5/weather?q=sola&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 56 which is for City: nouakchott
# http://api.openweathermap.org/data/2.5/weather?q=nouakchott&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 57 which is for City: georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 58 which is for City: saint george
# http://api.openweathermap.org/data/2.5/weather?q=saint george&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 59 which is for City: avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 60 which is for City: ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 61 which is for City: port-gentil
# http://api.openweathermap.org/data/2.5/weather?q=port-gentil&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 62 which is for City: lompoc
# http://api.openweathermap.org/data/2.5/weather?q=lompoc&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 63 which is for City: vaitupu
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 64 which is for City: cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 65 which is for City: khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 66 which is for City: flinders
# http://api.openweathermap.org/data/2.5/weather?q=flinders&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 67 which is for City: taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 68 which is for City: yenagoa
# http://api.openweathermap.org/data/2.5/weather?q=yenagoa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 69 which is for City: tongliao
# http://api.openweathermap.org/data/2.5/weather?q=tongliao&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 70 which is for City: lasa
# http://api.openweathermap.org/data/2.5/weather?q=lasa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 71 which is for City: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 72 which is for City: manga
# http://api.openweathermap.org/data/2.5/weather?q=manga&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 73 which is for City: astoria
# http://api.openweathermap.org/data/2.5/weather?q=astoria&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 74 which is for City: torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 75 which is for City: kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 76 which is for City: bairiki
# http://api.openweathermap.org/data/2.5/weather?q=bairiki&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 77 which is for City: druzhba
# http://api.openweathermap.org/data/2.5/weather?q=druzhba&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 78 which is for City: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 79 which is for City: damavand
# http://api.openweathermap.org/data/2.5/weather?q=damavand&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 80 which is for City: clyde river
# http://api.openweathermap.org/data/2.5/weather?q=clyde river&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 81 which is for City: plomarion
# http://api.openweathermap.org/data/2.5/weather?q=plomarion&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 82 which is for City: yavoriv
# http://api.openweathermap.org/data/2.5/weather?q=yavoriv&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 83 which is for City: port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 84 which is for City: belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 85 which is for City: roald
# http://api.openweathermap.org/data/2.5/weather?q=roald&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 86 which is for City: port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 87 which is for City: salalah
# http://api.openweathermap.org/data/2.5/weather?q=salalah&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 88 which is for City: miri
# http://api.openweathermap.org/data/2.5/weather?q=miri&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 89 which is for City: petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?q=petropavlovsk-kamchatskiy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 90 which is for City: ambon
# http://api.openweathermap.org/data/2.5/weather?q=ambon&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 91 which is for City: lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?q=lazaro cardenas&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 92 which is for City: aleksandrow kujawski
# http://api.openweathermap.org/data/2.5/weather?q=aleksandrow kujawski&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 93 which is for City: mopti
# http://api.openweathermap.org/data/2.5/weather?q=mopti&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 94 which is for City: kahului
# http://api.openweathermap.org/data/2.5/weather?q=kahului&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 95 which is for City: bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 96 which is for City: tokmak
# http://api.openweathermap.org/data/2.5/weather?q=tokmak&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 97 which is for City: teya
# http://api.openweathermap.org/data/2.5/weather?q=teya&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 98 which is for City: barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 99 which is for City: srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?q=srednekolymsk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 100 which is for City: veraval
# http://api.openweathermap.org/data/2.5/weather?q=veraval&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 101 which is for City: vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 102 which is for City: pasighat
# http://api.openweathermap.org/data/2.5/weather?q=pasighat&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 103 which is for City: ambilobe
# http://api.openweathermap.org/data/2.5/weather?q=ambilobe&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 104 which is for City: mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 105 which is for City: alice springs
# http://api.openweathermap.org/data/2.5/weather?q=alice springs&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 106 which is for City: olafsvik
# http://api.openweathermap.org/data/2.5/weather?q=olafsvik&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 107 which is for City: la victoria
# http://api.openweathermap.org/data/2.5/weather?q=la victoria&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 108 which is for City: tessalit
# http://api.openweathermap.org/data/2.5/weather?q=tessalit&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 109 which is for City: barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 110 which is for City: anqing
# http://api.openweathermap.org/data/2.5/weather?q=anqing&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 111 which is for City: oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?q=oktyabrskiy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 112 which is for City: arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 113 which is for City: kusk
# http://api.openweathermap.org/data/2.5/weather?q=kusk&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 114 which is for City: mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 115 which is for City: severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 116 which is for City: the valley
# http://api.openweathermap.org/data/2.5/weather?q=the valley&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 117 which is for City: bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 118 which is for City: pemangkat
# http://api.openweathermap.org/data/2.5/weather?q=pemangkat&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 119 which is for City: hervey bay
# http://api.openweathermap.org/data/2.5/weather?q=hervey bay&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 120 which is for City: east london
# http://api.openweathermap.org/data/2.5/weather?q=east london&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 121 which is for City: airai
# http://api.openweathermap.org/data/2.5/weather?q=airai&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 122 which is for City: nouadhibou
# http://api.openweathermap.org/data/2.5/weather?q=nouadhibou&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 123 which is for City: sao filipe
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 124 which is for City: luebo
# http://api.openweathermap.org/data/2.5/weather?q=luebo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 125 which is for City: rocha
# http://api.openweathermap.org/data/2.5/weather?q=rocha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 126 which is for City: arkhangelos
# http://api.openweathermap.org/data/2.5/weather?q=arkhangelos&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 127 which is for City: hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 128 which is for City: young
# http://api.openweathermap.org/data/2.5/weather?q=young&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 129 which is for City: sabzevar
# http://api.openweathermap.org/data/2.5/weather?q=sabzevar&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 130 which is for City: cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?q=cabo san lucas&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 131 which is for City: pitimbu
# http://api.openweathermap.org/data/2.5/weather?q=pitimbu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 132 which is for City: tumen
# http://api.openweathermap.org/data/2.5/weather?q=tumen&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 133 which is for City: wagar
# http://api.openweathermap.org/data/2.5/weather?q=wagar&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 134 which is for City: thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 135 which is for City: broome
# http://api.openweathermap.org/data/2.5/weather?q=broome&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 136 which is for City: kruisfontein
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 137 which is for City: kloulklubed
# http://api.openweathermap.org/data/2.5/weather?q=kloulklubed&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 138 which is for City: gilgit
# http://api.openweathermap.org/data/2.5/weather?q=gilgit&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 139 which is for City: ust-nera
# http://api.openweathermap.org/data/2.5/weather?q=ust-nera&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 140 which is for City: victoria
# http://api.openweathermap.org/data/2.5/weather?q=victoria&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 141 which is for City: okulovka
# http://api.openweathermap.org/data/2.5/weather?q=okulovka&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 142 which is for City: provideniya
# http://api.openweathermap.org/data/2.5/weather?q=provideniya&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 143 which is for City: cooma
# http://api.openweathermap.org/data/2.5/weather?q=cooma&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 144 which is for City: yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 145 which is for City: klaksvik
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 146 which is for City: wanaka
# http://api.openweathermap.org/data/2.5/weather?q=wanaka&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 147 which is for City: los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 148 which is for City: hasaki
# http://api.openweathermap.org/data/2.5/weather?q=hasaki&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 149 which is for City: shingu
# http://api.openweathermap.org/data/2.5/weather?q=shingu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 150 which is for City: sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?q=sao felix do xingu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 151 which is for City: muros
# http://api.openweathermap.org/data/2.5/weather?q=muros&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 152 which is for City: te anau
# http://api.openweathermap.org/data/2.5/weather?q=te anau&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 153 which is for City: riyadh
# http://api.openweathermap.org/data/2.5/weather?q=riyadh&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 154 which is for City: tostamaa
# http://api.openweathermap.org/data/2.5/weather?q=tostamaa&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 155 which is for City: tingo maria
# http://api.openweathermap.org/data/2.5/weather?q=tingo maria&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 156 which is for City: kawalu
# http://api.openweathermap.org/data/2.5/weather?q=kawalu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 157 which is for City: karratha
# http://api.openweathermap.org/data/2.5/weather?q=karratha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 158 which is for City: tumannyy
# http://api.openweathermap.org/data/2.5/weather?q=tumannyy&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 159 which is for City: maniitsoq
# http://api.openweathermap.org/data/2.5/weather?q=maniitsoq&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 160 which is for City: ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 161 which is for City: magui
# http://api.openweathermap.org/data/2.5/weather?q=magui&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 162 which is for City: tautira
# http://api.openweathermap.org/data/2.5/weather?q=tautira&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 163 which is for City: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 164 which is for City: susanville
# http://api.openweathermap.org/data/2.5/weather?q=susanville&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 165 which is for City: poum
# http://api.openweathermap.org/data/2.5/weather?q=poum&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 166 which is for City: kjollefjord
# http://api.openweathermap.org/data/2.5/weather?q=kjollefjord&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 167 which is for City: carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 168 which is for City: lao cai
# http://api.openweathermap.org/data/2.5/weather?q=lao cai&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 169 which is for City: ilulissat
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 170 which is for City: labuhan
# http://api.openweathermap.org/data/2.5/weather?q=labuhan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 171 which is for City: den helder
# http://api.openweathermap.org/data/2.5/weather?q=den helder&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 172 which is for City: zhigansk
# http://api.openweathermap.org/data/2.5/weather?q=zhigansk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 173 which is for City: saint anthony
# http://api.openweathermap.org/data/2.5/weather?q=saint anthony&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 174 which is for City: alofi
# http://api.openweathermap.org/data/2.5/weather?q=alofi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 175 which is for City: guerrero negro
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 176 which is for City: hofn
# http://api.openweathermap.org/data/2.5/weather?q=hofn&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 177 which is for City: zhaoyuan
# http://api.openweathermap.org/data/2.5/weather?q=zhaoyuan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 178 which is for City: ust-barguzin
# http://api.openweathermap.org/data/2.5/weather?q=ust-barguzin&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 179 which is for City: altamont
# http://api.openweathermap.org/data/2.5/weather?q=altamont&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 180 which is for City: yingcheng
# http://api.openweathermap.org/data/2.5/weather?q=yingcheng&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 181 which is for City: dodoma
# http://api.openweathermap.org/data/2.5/weather?q=dodoma&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 182 which is for City: mitu
# http://api.openweathermap.org/data/2.5/weather?q=mitu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 183 which is for City: ndjole
# http://api.openweathermap.org/data/2.5/weather?q=ndjole&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 184 which is for City: kaspiysk
# http://api.openweathermap.org/data/2.5/weather?q=kaspiysk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 185 which is for City: valparaiso
# http://api.openweathermap.org/data/2.5/weather?q=valparaiso&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 186 which is for City: labrea
# http://api.openweathermap.org/data/2.5/weather?q=labrea&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 187 which is for City: antalaha
# http://api.openweathermap.org/data/2.5/weather?q=antalaha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 188 which is for City: narsaq
# http://api.openweathermap.org/data/2.5/weather?q=narsaq&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 189 which is for City: plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?q=plettenberg bay&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 190 which is for City: kismayo
# http://api.openweathermap.org/data/2.5/weather?q=kismayo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 191 which is for City: kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?q=kudahuvadhoo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 192 which is for City: tungkang
# http://api.openweathermap.org/data/2.5/weather?q=tungkang&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 193 which is for City: camacha
# http://api.openweathermap.org/data/2.5/weather?q=camacha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 194 which is for City: isangel
# http://api.openweathermap.org/data/2.5/weather?q=isangel&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 195 which is for City: alice
# http://api.openweathermap.org/data/2.5/weather?q=alice&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 196 which is for City: new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 197 which is for City: laguna
# http://api.openweathermap.org/data/2.5/weather?q=laguna&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 198 which is for City: vanimo
# http://api.openweathermap.org/data/2.5/weather?q=vanimo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 199 which is for City: svetlyy
# http://api.openweathermap.org/data/2.5/weather?q=svetlyy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 200 which is for City: kalghatgi
# http://api.openweathermap.org/data/2.5/weather?q=kalghatgi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 201 which is for City: williamsport
# http://api.openweathermap.org/data/2.5/weather?q=williamsport&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 202 which is for City: sinnamary
# http://api.openweathermap.org/data/2.5/weather?q=sinnamary&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 203 which is for City: beloha
# http://api.openweathermap.org/data/2.5/weather?q=beloha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 204 which is for City: tshela
# http://api.openweathermap.org/data/2.5/weather?q=tshela&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 205 which is for City: tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 206 which is for City: saint-joseph
# http://api.openweathermap.org/data/2.5/weather?q=saint-joseph&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 207 which is for City: maldonado
# http://api.openweathermap.org/data/2.5/weather?q=maldonado&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 208 which is for City: palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?q=palabuhanratu&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 209 which is for City: attawapiskat
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 210 which is for City: pisco
# http://api.openweathermap.org/data/2.5/weather?q=pisco&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 211 which is for City: tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 212 which is for City: xichang
# http://api.openweathermap.org/data/2.5/weather?q=xichang&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 213 which is for City: landeck
# http://api.openweathermap.org/data/2.5/weather?q=landeck&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 214 which is for City: samana
# http://api.openweathermap.org/data/2.5/weather?q=samana&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 215 which is for City: la libertad
# http://api.openweathermap.org/data/2.5/weather?q=la libertad&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 216 which is for City: cedar city
# http://api.openweathermap.org/data/2.5/weather?q=cedar city&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 217 which is for City: gunnedah
# http://api.openweathermap.org/data/2.5/weather?q=gunnedah&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 218 which is for City: comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?q=comodoro rivadavia&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 219 which is for City: wanning
# http://api.openweathermap.org/data/2.5/weather?q=wanning&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 220 which is for City: chokwe
# http://api.openweathermap.org/data/2.5/weather?q=chokwe&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 221 which is for City: kununurra
# http://api.openweathermap.org/data/2.5/weather?q=kununurra&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 222 which is for City: ajdabiya
# http://api.openweathermap.org/data/2.5/weather?q=ajdabiya&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 223 which is for City: richards bay
# http://api.openweathermap.org/data/2.5/weather?q=richards bay&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 224 which is for City: mecca
# http://api.openweathermap.org/data/2.5/weather?q=mecca&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 225 which is for City: price
# http://api.openweathermap.org/data/2.5/weather?q=price&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 226 which is for City: nguiu
# http://api.openweathermap.org/data/2.5/weather?q=nguiu&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 227 which is for City: allonnes
# http://api.openweathermap.org/data/2.5/weather?q=allonnes&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 228 which is for City: liberal
# http://api.openweathermap.org/data/2.5/weather?q=liberal&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 229 which is for City: natchez
# http://api.openweathermap.org/data/2.5/weather?q=natchez&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 230 which is for City: port blair
# http://api.openweathermap.org/data/2.5/weather?q=port blair&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 231 which is for City: filadelfia
# http://api.openweathermap.org/data/2.5/weather?q=filadelfia&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 232 which is for City: rio gallegos
# http://api.openweathermap.org/data/2.5/weather?q=rio gallegos&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 233 which is for City: mizan teferi
# http://api.openweathermap.org/data/2.5/weather?q=mizan teferi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 234 which is for City: unai
# http://api.openweathermap.org/data/2.5/weather?q=unai&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 235 which is for City: tukrah
# http://api.openweathermap.org/data/2.5/weather?q=tukrah&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 236 which is for City: itarema
# http://api.openweathermap.org/data/2.5/weather?q=itarema&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 237 which is for City: nabire
# http://api.openweathermap.org/data/2.5/weather?q=nabire&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 238 which is for City: cabo rojo
# http://api.openweathermap.org/data/2.5/weather?q=cabo rojo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 239 which is for City: ipixuna
# http://api.openweathermap.org/data/2.5/weather?q=ipixuna&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 240 which is for City: vojens
# http://api.openweathermap.org/data/2.5/weather?q=vojens&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 241 which is for City: tofield
# http://api.openweathermap.org/data/2.5/weather?q=tofield&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 242 which is for City: mogadishu
# http://api.openweathermap.org/data/2.5/weather?q=mogadishu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 243 which is for City: paranhos
# http://api.openweathermap.org/data/2.5/weather?q=paranhos&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 244 which is for City: ouango
# http://api.openweathermap.org/data/2.5/weather?q=ouango&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 245 which is for City: san patricio
# http://api.openweathermap.org/data/2.5/weather?q=san patricio&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 246 which is for City: morro bay
# http://api.openweathermap.org/data/2.5/weather?q=morro bay&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 247 which is for City: zakamensk
# http://api.openweathermap.org/data/2.5/weather?q=zakamensk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 248 which is for City: vilyuysk
# http://api.openweathermap.org/data/2.5/weather?q=vilyuysk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 249 which is for City: obo
# http://api.openweathermap.org/data/2.5/weather?q=obo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 250 which is for City: talnakh
# http://api.openweathermap.org/data/2.5/weather?q=talnakh&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 251 which is for City: tazovskiy
# http://api.openweathermap.org/data/2.5/weather?q=tazovskiy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 252 which is for City: rosamorada
# http://api.openweathermap.org/data/2.5/weather?q=rosamorada&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 253 which is for City: caravelas
# http://api.openweathermap.org/data/2.5/weather?q=caravelas&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 254 which is for City: maine-soroa
# http://api.openweathermap.org/data/2.5/weather?q=maine-soroa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 255 which is for City: roma
# http://api.openweathermap.org/data/2.5/weather?q=roma&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 256 which is for City: longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 257 which is for City: codrington
# http://api.openweathermap.org/data/2.5/weather?q=codrington&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 258 which is for City: murdochville
# http://api.openweathermap.org/data/2.5/weather?q=murdochville&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 259 which is for City: maceio
# http://api.openweathermap.org/data/2.5/weather?q=maceio&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 260 which is for City: chara
# http://api.openweathermap.org/data/2.5/weather?q=chara&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 261 which is for City: aylesbury
# http://api.openweathermap.org/data/2.5/weather?q=aylesbury&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 262 which is for City: fortuna
# http://api.openweathermap.org/data/2.5/weather?q=fortuna&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 263 which is for City: nyurba
# http://api.openweathermap.org/data/2.5/weather?q=nyurba&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 264 which is for City: swan river
# http://api.openweathermap.org/data/2.5/weather?q=swan river&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 265 which is for City: chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 266 which is for City: kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 267 which is for City: san francisco
# http://api.openweathermap.org/data/2.5/weather?q=san francisco&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 268 which is for City: homer
# http://api.openweathermap.org/data/2.5/weather?q=homer&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 269 which is for City: victor harbor
# http://api.openweathermap.org/data/2.5/weather?q=victor harbor&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 270 which is for City: broken hill
# http://api.openweathermap.org/data/2.5/weather?q=broken hill&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 271 which is for City: haapiti
# http://api.openweathermap.org/data/2.5/weather?q=haapiti&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 272 which is for City: mehamn
# http://api.openweathermap.org/data/2.5/weather?q=mehamn&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 273 which is for City: lancaster
# http://api.openweathermap.org/data/2.5/weather?q=lancaster&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 274 which is for City: lorengau
# http://api.openweathermap.org/data/2.5/weather?q=lorengau&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 275 which is for City: saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 276 which is for City: ondangwa
# http://api.openweathermap.org/data/2.5/weather?q=ondangwa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 277 which is for City: rundu
# http://api.openweathermap.org/data/2.5/weather?q=rundu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 278 which is for City: namtsy
# http://api.openweathermap.org/data/2.5/weather?q=namtsy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 279 which is for City: hirara
# http://api.openweathermap.org/data/2.5/weather?q=hirara&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 280 which is for City: kedrovyy
# http://api.openweathermap.org/data/2.5/weather?q=kedrovyy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 281 which is for City: pajan
# ...
# 200
# Processing request for index number: 536 which is for City: halifax
# http://api.openweathermap.org/data/2.5/weather?q=halifax&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 537 which is for City: mendahara
# http://api.openweathermap.org/data/2.5/weather?q=mendahara&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 538 which is for City: tingrela
# http://api.openweathermap.org/data/2.5/weather?q=tingrela&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 539 which is for City: portland
# http://api.openweathermap.org/data/2.5/weather?q=portland&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 540 which is for City: moyale
# http://api.openweathermap.org/data/2.5/weather?q=moyale&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 541 which is for City: sunrise manor
# http://api.openweathermap.org/data/2.5/weather?q=sunrise manor&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 542 which is for City: wuning
# http://api.openweathermap.org/data/2.5/weather?q=wuning&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 543 which is for City: bargal
# http://api.openweathermap.org/data/2.5/weather?q=bargal&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 544 which is for City: yumen
# http://api.openweathermap.org/data/2.5/weather?q=yumen&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 545 which is for City: kapit
# http://api.openweathermap.org/data/2.5/weather?q=kapit&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 546 which is for City: iquitos
# http://api.openweathermap.org/data/2.5/weather?q=iquitos&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 547 which is for City: acarau
# http://api.openweathermap.org/data/2.5/weather?q=acarau&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 548 which is for City: high level
# http://api.openweathermap.org/data/2.5/weather?q=high level&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 549 which is for City: eskasem
# http://api.openweathermap.org/data/2.5/weather?q=eskasem&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 550 which is for City: polunochnoye
# http://api.openweathermap.org/data/2.5/weather?q=polunochnoye&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 551 which is for City: geraldton
# http://api.openweathermap.org/data/2.5/weather?q=geraldton&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 552 which is for City: jiuquan
# http://api.openweathermap.org/data/2.5/weather?q=jiuquan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 553 which is for City: odweyne
# http://api.openweathermap.org/data/2.5/weather?q=odweyne&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 554 which is for City: fort nelson
# http://api.openweathermap.org/data/2.5/weather?q=fort nelson&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 555 which is for City: warqla
# http://api.openweathermap.org/data/2.5/weather?q=warqla&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 556 which is for City: ayan
# http://api.openweathermap.org/data/2.5/weather?q=ayan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 557 which is for City: kamenskoye
# http://api.openweathermap.org/data/2.5/weather?q=kamenskoye&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 558 which is for City: zhuhai
# http://api.openweathermap.org/data/2.5/weather?q=zhuhai&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 559 which is for City: gagarin
# http://api.openweathermap.org/data/2.5/weather?q=gagarin&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 560 which is for City: korla
# http://api.openweathermap.org/data/2.5/weather?q=korla&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 561 which is for City: klyuchi
# http://api.openweathermap.org/data/2.5/weather?q=klyuchi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 562 which is for City: puerto penasco
# http://api.openweathermap.org/data/2.5/weather?q=puerto penasco&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 563 which is for City: port hardy
# http://api.openweathermap.org/data/2.5/weather?q=port hardy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 564 which is for City: iroquois falls
# http://api.openweathermap.org/data/2.5/weather?q=iroquois falls&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 565 which is for City: sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 566 which is for City: dingle
# http://api.openweathermap.org/data/2.5/weather?q=dingle&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 567 which is for City: albuquerque
# http://api.openweathermap.org/data/2.5/weather?q=albuquerque&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 568 which is for City: tangjiazhuang
# http://api.openweathermap.org/data/2.5/weather?q=tangjiazhuang&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 569 which is for City: ahmadabad
# http://api.openweathermap.org/data/2.5/weather?q=ahmadabad&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 570 which is for City: jujuy
# http://api.openweathermap.org/data/2.5/weather?q=jujuy&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 571 which is for City: bhandara
# http://api.openweathermap.org/data/2.5/weather?q=bhandara&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 572 which is for City: arkhangelsk
# http://api.openweathermap.org/data/2.5/weather?q=arkhangelsk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 573 which is for City: beroroha
# http://api.openweathermap.org/data/2.5/weather?q=beroroha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 574 which is for City: wana
# http://api.openweathermap.org/data/2.5/weather?q=wana&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 575 which is for City: orange cove
# http://api.openweathermap.org/data/2.5/weather?q=orange cove&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 576 which is for City: north bend
# http://api.openweathermap.org/data/2.5/weather?q=north bend&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 577 which is for City: waipawa
# http://api.openweathermap.org/data/2.5/weather?q=waipawa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 578 which is for City: ilhabela
# http://api.openweathermap.org/data/2.5/weather?q=ilhabela&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 579 which is for City: finnsnes
# http://api.openweathermap.org/data/2.5/weather?q=finnsnes&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 580 which is for City: kaputa
# http://api.openweathermap.org/data/2.5/weather?q=kaputa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 581 which is for City: dali
# http://api.openweathermap.org/data/2.5/weather?q=dali&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 582 which is for City: aktas
# http://api.openweathermap.org/data/2.5/weather?q=aktas&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 583 which is for City: general roca
# http://api.openweathermap.org/data/2.5/weather?q=general roca&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 584 which is for City: painesville
# http://api.openweathermap.org/data/2.5/weather?q=painesville&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 585 which is for City: balkhash
# http://api.openweathermap.org/data/2.5/weather?q=balkhash&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 586 which is for City: mastic beach
# http://api.openweathermap.org/data/2.5/weather?q=mastic beach&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 587 which is for City: cockburn harbour
# http://api.openweathermap.org/data/2.5/weather?q=cockburn harbour&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 588 which is for City: kavaratti
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 589 which is for City: scottsburgh
# http://api.openweathermap.org/data/2.5/weather?q=scottsburgh&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 590 which is for City: kathu
# http://api.openweathermap.org/data/2.5/weather?q=kathu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 591 which is for City: aksha
# http://api.openweathermap.org/data/2.5/weather?q=aksha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 592 which is for City: jibuti
# http://api.openweathermap.org/data/2.5/weather?q=jibuti&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 593 which is for City: altay
# http://api.openweathermap.org/data/2.5/weather?q=altay&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 594 which is for City: sioux lookout
# http://api.openweathermap.org/data/2.5/weather?q=sioux lookout&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 595 which is for City: wad rawah
# http://api.openweathermap.org/data/2.5/weather?q=wad rawah&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 596 which is for City: malatya
# http://api.openweathermap.org/data/2.5/weather?q=malatya&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 597 which is for City: iqaluit
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 598 which is for City: huarmey
# http://api.openweathermap.org/data/2.5/weather?q=huarmey&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 599 which is for City: quibor
# http://api.openweathermap.org/data/2.5/weather?q=quibor&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 600 which is for City: milkovo
# http://api.openweathermap.org/data/2.5/weather?q=milkovo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 601 which is for City: wad madani
# http://api.openweathermap.org/data/2.5/weather?q=wad madani&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 602 which is for City: daru
# http://api.openweathermap.org/data/2.5/weather?q=daru&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 603 which is for City: beya
# http://api.openweathermap.org/data/2.5/weather?q=beya&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 604 which is for City: presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?q=presidencia roque saenz pena&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 605 which is for City: bac lieu
# http://api.openweathermap.org/data/2.5/weather?q=bac lieu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 606 which is for City: khani
# http://api.openweathermap.org/data/2.5/weather?q=khani&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 607 which is for City: birao
# http://api.openweathermap.org/data/2.5/weather?q=birao&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 608 which is for City: mentok
# http://api.openweathermap.org/data/2.5/weather?q=mentok&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 609 which is for City: itaperucu
# http://api.openweathermap.org/data/2.5/weather?q=itaperucu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 610 which is for City: crab hill
# http://api.openweathermap.org/data/2.5/weather?q=crab hill&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 611 which is for City: mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 612 which is for City: akyab
# http://api.openweathermap.org/data/2.5/weather?q=akyab&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 613 which is for City: yaan
# http://api.openweathermap.org/data/2.5/weather?q=yaan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 614 which is for City: buraydah
# http://api.openweathermap.org/data/2.5/weather?q=buraydah&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 615 which is for City: sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?q=sao joao da barra&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 616 which is for City: oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?q=oktyabrskoye&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 617 which is for City: sanchor
# http://api.openweathermap.org/data/2.5/weather?q=sanchor&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 618 which is for City: marcona
# http://api.openweathermap.org/data/2.5/weather?q=marcona&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 619 which is for City: andevoranto
# http://api.openweathermap.org/data/2.5/weather?q=andevoranto&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 620 which is for City: mandal
# http://api.openweathermap.org/data/2.5/weather?q=mandal&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 621 which is for City: luderitz
# http://api.openweathermap.org/data/2.5/weather?q=luderitz&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 622 which is for City: rodrigues alves
# http://api.openweathermap.org/data/2.5/weather?q=rodrigues alves&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 623 which is for City: tilichiki
# http://api.openweathermap.org/data/2.5/weather?q=tilichiki&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 624 which is for City: baykit
# http://api.openweathermap.org/data/2.5/weather?q=baykit&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 625 which is for City: berea
# http://api.openweathermap.org/data/2.5/weather?q=berea&appid=397b95f1b822905242cabd4b62006f61
# 200
#               City Country    Lat     Lon    Temp  Humidity  Cloudiness  \
# 0        purranque      CL -40.92  -73.17  39.200        86           0
# 1    mount gambier      AU -37.83  140.77  60.800        67          90
# 2          aksarka      RU  66.56   67.80  19.760        98          99
# 3         rochegda      RU  62.80   43.25  24.584        99          72
# 4  bambous virieux      MU -20.34   57.76  77.486        69          75
#
#    Windspeed
# 0   5.816044
# 1  12.750558
# 2   8.947760
# 3   4.764682
# 4  12.750558

# %% [markdown]
# *Create a DataFrame of the weathercheck data*

# %%
weather_check_df = pd.DataFrame({ "City" : city_df['City'],
                                  "Latitude" : city_df['Lat'],
                                  "Longitude" : city_df['Lon'],
                                  "Temperature(F)" : city_df['Temp'],
                                  "Humidity%" : city_df['Humidity'],
                                  "Cloudiness%" : city_df['Cloudiness'],
                                  "Wind Speed(mph)" : city_df['Windspeed'] })                                                         

weather_check_df.head()
# Out:
#               City  Latitude  Longitude  Temperature(F)  Humidity%  \
# 0        purranque    -40.92     -73.17          39.200         86
# 1    mount gambier    -37.83     140.77          60.800         67
# 2          aksarka     66.56      67.80          19.760         98
# 3         rochegda     62.80      43.25          24.584         99
# 4  bambous virieux    -20.34      57.76          77.486         69
#
#    Cloudiness%  Wind Speed(mph)
# 0            0         5.816044
# 1           90        12.750558
# 2           99         8.947760
# 3           72         4.764682
# 4           75        12.750558

# %% [markdown]
# *Definining a function called 'scatter_plot' for plotting the visualization*

# %%
def scatter_plot(x_values,y_values,x_label,y_label,title,regress):
    plt.scatter(x_values,y_values,marker="o", facecolors="red", edgecolors="black",s=30, alpha=0.75)
    if regress==True:
        (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
        regress_values = x_values * slope + intercept
        line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
        r_sq = "r-sq="+str(round(rvalue,2))
        plt.plot(x_values,regress_values,"r-")
        
        x_location=round(np.percentile(x_values,50),0)
        y_location=round(np.percentile(regress_values,50),0)
               
        plt.annotate(line_eq, (x_location,y_location), fontsize=12,color="green")
        plt.annotate(r_sq, (x_location,y_location-10), fontsize=12,color="green")
    
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# %% [markdown]
# *Definining a function called 'save_image'*

# %%
def save_image(x_values,y_values,x_label,y_label,title, regress):
    scatter_plot(x_values,y_values,x_label,y_label,title,regress)
    plt.savefig(f"python-AP-challenge\{title}.png")
    plt.show()

# %%
#Defining a list of weather data to be x - values & regions for plotting latitude vs weather data
weather_info = ['Temperature(F)', 'Humidity%', 'Cloudiness%', 'Wind Speed(mph)']
regress=False
for info in weather_info:
    print(f"Plotting & saving the scatter chart of {info} vs. Latitude")
    x_values = weather_check_df[info]
    y_values = weather_check_df['Latitude']
    x_label = info
    y_label = "Latitude (degrees)"
    title = f"{info}_vs_Latitude"
    save_image(x_values,y_values,x_label,y_label,title,regress)
# Out:
# Plotting & saving the scatter chart of Temperature(F) vs. Latitude
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-8e7185ee3c29> in <module>
#       9     y_label = "Latitude (degrees)"
#      10     title = f"{info}_vs_Latitude"
# ---> 11     save_image(x_values,y_values,x_label,y_label,title,regress)
#
# <ipython-input-14-24dd3190242f> in save_image(x_values, y_values, x_label, y_label, title, regress)
#       1 def save_image(x_values,y_values,x_label,y_label,title, regress):
#       2     scatter_plot(x_values,y_values,x_label,y_label,title,regress)
# ----> 3     plt.savefig(f"python-api-challenge\{title}.png")
#       4     plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2117
#    2118             try:
# -> 2119                 result = print_method(
#    2120                     filename,
#    2121                     dpi=dpi,
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python-api-challenge\\Temperature(F)_vs_Latitude.png'

# %%
# We need northern_hemisphere_weather_df and southern_hemisphere_weather_df out of weather_check_df
northern_hemisphere_weather_df = weather_check_df[weather_check_df['Latitude'] >= 0]
southern_hemisphere_weather_df = weather_check_df[weather_check_df['Latitude'] < 0]

#This block will call the function scatter_plot and provide parameters as defined below
regions = ['Northern_Hemisphere','Southern_Hemisphere']
#Defining a list of weather data to be x - values & regions for plotting
weather_info = ['Temperature(F)', 'Humidity%', 'Cloudiness%', 'Wind Speed(mph)']
#print overall parameters vs latitude without regression
regress=True
for region in regions:
    for info in weather_info:
        if region == 'Northern_Hemisphere':
            print(f"Plotting & saving the scatter chart of {region} - {info} vs. Latitude")
            weather_data_df = northern_hemisphere_weather_df
        elif region == 'Southern_Hemisphere':
            print(f"Plotting & saving the scatter chart of {region} - {info} vs. Latitude")
            weather_data_df = southern_hemisphere_weather_df  
        x_values = weather_data_df[info]
        y_values = weather_data_df['Latitude']
        x_label = info
        y_label = "Latitude (degrees)"
        title = f"{region} - {info}_vs_Latitude"
        save_image(x_values,y_values,x_label,y_label,title,regress)

# %% [markdown]
# '''
# Inferences from the Graphs:
# Temperature has strong correlation the latitude of a city.
# There is strong positive correlation in Southern hemisphere(when the latitude increases, the temperature also increases and vice versa),
# and strong negative correlation(as latitude increases, temperature decreases and vice versa) in the Northern hemisphere.
#
# There is no indication of any correlation between humidity OR cloudiness with the latitude of a city.
#
# Also, there is no significant correlation between wind speed and latitude, but wind speed
# appears to be a constant in the cities belonging in the northern hemisphere.
# '''
