# %%
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint
import pprint 
from config1 import w_key
from citipy import citipy

# %% [markdown]
# *We need a list of cities to gather weather data. We will now generate a list of cities and then create a dataframe of the cities, and also export the cities to a CSV file.*

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
duplicated = []
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)
# Identify nearest city for each lat, lng combination
i = 1
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
   # print(f"record {i}", {lat_lng[0], lat_lng[1]}, {city})
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
    else:
        duplicated.append(city)
    i = i+1
print('\n')
print(f"Duplicated cities = {duplicated}")
print('\n')
# Print the city count to confirm sufficient count
print('\n')
print(f"Cities that will be used for analysis = {cities}")
print('\n')
print(f" Leaving behind the duplicated cities, the count of cities =  {len(cities)}")
# Out:
# Duplicated cities = ['ushuaia', 'rikitea', 'rikitea', 'busselton', 'hobart', 'rikitea', 'victoria', 'ushuaia', 'ushuaia', 'puerto ayora', 'upernavik', 'ushuaia', 'busselton', 'coihaique', 'puerto ayora', 'dikson', 'rikitea', 'butaritari', 'hilo', 'port elizabeth', 'victoria', 'tahe', 'punta arenas', 'longyearbyen', 'ushuaia', 'tuktoyaktuk', 'tiksi', 'olafsvik', 'puerto ayora', 'longyearbyen', 'ushuaia', 'busselton', 'carnarvon', 'bredasdorp', 'pevek', 'sao filipe', 'taolanaro', 'mataura', 'rikitea', 'rikitea', 'dikson', 'upernavik', 'rikitea', 'bredasdorp', 'rikitea', 'rikitea', 'hobart', 'puerto ayora', 'hobart', 'taolanaro', 'bredasdorp', 'hermanus', 'ushuaia', 'ushuaia', 'vaini', 'hermanus', 'ushuaia', 'dingle', 'ahipara', 'tuatapere', 'barrow', 'ushuaia', 'ushuaia', 'salalah', 'chuy', 'ushuaia', 'cape town', 'upernavik', 'dikson', 'upernavik', 'hithadhoo', 'port alfred', 'portland', 'laguna', 'tiksi', 'illoqqortoormiut', 'port alfred', 'busselton', 'punta arenas', 'ushuaia', 'rikitea', 'thompson', 'hobart', 'qaanaaq', 'ushuaia', 'rikitea', 'puerto ayora', 'rocha', 'riyadh', 'jamestown', 'bluff', 'hithadhoo', 'avarua', 'upernavik', 'mataura', 'upernavik', 'taolanaro', 'saskylakh', 'albany', 'punta arenas', 'cabo san lucas', 'hermanus', 'tuktoyaktuk', 'tiksi', 'bambous virieux', 'albany', 'rikitea', 'punta arenas', 'puerto ayora', 'hermanus', 'albany', 'bredasdorp', 'albany', 'thompson', 'thompson', 'punta arenas', 'bethel', 'hobart', 'atuona', 'torbay', 'ponta do sol', 'bengkulu', 'rikitea', 'ushuaia', 'nome', 'qaanaaq', 'hobart', 'vaini', 'puerto ayora', 'puerto ayora', 'hobart', 'puerto ayora', 'taolanaro', 'albany', 'ribeira grande', 'butaritari', 'thompson', 'lebu', 'port alfred', 'rawson', 'ushuaia', 'hermanus', 'mataura', 'bredasdorp', 'tuktoyaktuk', 'punta arenas', 'saskylakh', 'vaini', 'east london', 'arraial do cabo', 'rikitea', 'busselton', 'kavieng', 'arraial do cabo', 'cape town', 'hithadhoo', 'constitucion', 'ushuaia', 'albany', 'sibolga', 'hobart', 'arraial do cabo', 'vaini', 'nikolskoye', 'punta arenas', 'port alfred', 'upernavik', 'taolanaro', 'albany', 'port alfred', 'bluff', 'east london', 'vaini', 'kapaa', 'cape town', 'kavieng', 'ushuaia', 'mahebourg', 'padang', 'bambous virieux', 'albany', 'mar del plata', 'cape town', 'hermanus', 'punta arenas', 'thompson', 'hobart', 'salalah', 'mataura', 'punta arenas', 'port alfred', 'hilo', 'tasiilaq', 'ushuaia', 'esperance', 'bredasdorp', 'taolanaro', 'ushuaia', 'barrow', 'mataura', 'tiznit', 'busselton', 'punta arenas', 'busselton', 'bluff', 'east london', 'cherskiy', 'longyearbyen', 'hilo', 'cherskiy', 'saint-philippe', 'atuona', 'broken hill', 'jamestown', 'rikitea', 'bluff', 'bredasdorp', 'port blair', 'tuktoyaktuk', 'rikitea', 'barentsburg', 'ilulissat', 'new norfolk', 'bethel', 'vaini', 'bluff', 'severo-kurilsk', 'busselton', 'atuona', 'punta arenas', 'punta arenas', 'codrington', 'rikitea', 'taolanaro', 'arraial do cabo', 'bluff', 'new norfolk', 'new norfolk', 'bredasdorp', 'fortuna', 'ribeira grande', 'rikitea', 'carnarvon', 'nanortalik', 'bredasdorp', 'punta arenas', 'namibe', 'punta arenas', 'rikitea', 'khatanga', 'jamestown', 'belushya guba', 'hobart', 'bredasdorp', 'avarua', 'vaini', 'new norfolk', 'barentsburg', 'mataura', 'barrow', 'arraial do cabo', 'rikitea', 'tiksi', 'qaanaaq', 'jamestown', 'hithadhoo', 'tasiilaq', 'taolanaro', 'east london', 'rikitea', 'rikitea', 'torbay', 'puerto ayora', 'ribeira grande', 'victoria', 'punta arenas', 'puerto ayora', 'salalah', 'bambous virieux', 'pevek', 'yellowknife', 'new norfolk', 'atuona', 'fairbanks', 'port alfred', 'petropavlovsk-kamchatskiy', 'arraial do cabo', 'busselton', 'kristiinankaupunki', 'carnarvon', 'butaritari', 'rikitea', 'puerto ayora', 'castro', 'bluff', 'ushuaia', 'rikitea', 'taolanaro', 'hasaki', 'jamestown', 'atuona', 'upernavik', 'naze', 'port alfred', 'jamestown', 'souillac', 'clyde river', 'albany', 'atuona', 'sitka', 'bluff', 'chuy', 'mahebourg', 'bilibino', 'mount gambier', 'grand river ...
#
#
#
#
# Cities that will be used for analysis = ['cape town', 'labuhan', 'la ronge', 'rikitea', 'olafsvik', 'yellowknife', 'hobart', 'cabo san lucas', 'ushuaia', 'ewa beach', 'clarksburg', 'puerto ayora', 'rocha', 'ambanja', 'busselton', 'ponta do sol', 'coihaique', 'college', 'fort nelson', 'hithadhoo', 'asau', 'mrirt', 'tuktoyaktuk', 'aljezur', 'sao filipe', 'akyab', 'apatity', 'port elizabeth', 'lansing', 'otofuke', 'hilo', 'kavaratti', 'punta arenas', 'victoria', 'dali', 'dingle', 'barrow', 'hermanus', 'andra', 'laguna', 'cedar city', 'castro', 'upernavik', 'donskoye', 'tahe', 'rudnichnyy', 'butaritari', 'padang', 'bambous virieux', 'provideniya', 'illoqqortoormiut', 'vao', 'karamea', 'freeport', 'maxixe', 'lebu', 'arraial do cabo', 'vaini', 'coahuayana', 'umm lajj', 'dikson', 'matagami', 'jamsa', 'robertsport', 'bredasdorp', 'kamenskoye', 'longyearbyen', 'general roca', 'am timan', 'tilsonburg', 'kalaleh', 'puchezh', 'ilebo', 'port macquarie', 'petropavlovsk-kamchatskiy', 'iaciara', 'tiksi', 'komsomolskiy', 'libreville', 'salalah', 'brae', 'port alfred', 'norman wells', 'new norfolk', 'marystown', 'marfino', 'beroroha', 'kristiinankaupunki', 'meridian', 'saleaula', 'taolanaro', 'jacareacanga', 'nikolskoye', 'severo-kurilsk', 'ilulissat', 'ahipara', 'tuatapere', 'pevek', 'nortelandia', 'fukue', 'albany', 'souillac', 'kavieng', 'carnarvon', 'mataura', 'vila', 'san luis', 'jinxi', 'henties bay', 'ternate', 'ucluelet', 'bluff', 'mar del plata', 'lyantonde', 'bloomfield', 'scottsbluff', 'grand river south east', 'chuy', 'cockburn town', 'la rioja', 'mayo', 'lower hutt', 'cururupu', 'khatanga', 'east london', 'nioro', 'neuquen', 'qaanaaq', 'tsihombe', 'cherskiy', 'casas grandes', 'san jose', 'koutiala', 'namatanai', 'chachapoyas', 'florence', 'aykhal', 'naze', 'taltal', 'jamestown', 'matli', 'avarua', 'riyadh', 'san rafael del sur', 'faanui', 'kaitangata', 'vanimo', 'portland', 'grand gaube', 'kapaa', 'sehithwa', 'rancho palos verdes', 'manado', 'puerto boyaca', 'aklavik', 'thompson', 'sao jose da coroa grande', 'hasaki', 'karratha', 'saskylakh', 'mitake', 'darnah', 'karlshus', 'esperance', 'madimba', 'bengkulu', 'sept-iles', 'atuona', 'sibolga', 'port-cartier', 'duluth', 'pemangkat', 'broken hill', 'miyako', 'colares', 'khor', 'makakilo city', 'nang rong', 'trinidad', 'ugoofaaru', 'sambava', 'marsh harbour', 'necochea', 'la palma', 'torbay', 'les cayes', 'srandakan', 'tasiilaq', 'nome', 'bethel', 'ribeira grande', 'rawson', 'kalmar', 'port hedland', 'fort-shevchenko', 'constitucion', 'narsaq', 'araouane', 'bolungarvik', 'high level', 'gondanglegi', 'aksu', 'oussouye', 'caucaia', 'tessalit', 'esmeraldas', 'arica', 'isangel', 'mount gambier', 'mahebourg', 'giyon', 'santa cruz', 'etla', 'mount isa', 'hay river', 'imbituva', 'hailar', 'takoradi', 'xiongshi', 'sorong', 'port-gentil', 'mayumba', 'avera', 'amderma', 'port lincoln', 'usinsk', 'anadyr', 'fortuna', 'bonthe', 'fairbanks', 'jiazi', 'samusu', 'havre-saint-pierre', 'khani', 'alta floresta', 'saint-philippe', 'ghanzi', 'nanzhang', 'bargal', 'tiznit', 'bakau', 'sisophon', 'port moresby', 'little elm', 'abu samrah', 'dickinson', 'danville', 'hermiston', 'luderitz', 'presidencia roque saenz pena', 'kashan', 'omboue', 'bilibino', 'camacha', 'waingapu', 'port blair', 'nanortalik', 'miri', 'aparecida', 'aflu', 'hofn', 'sitka', 'sungaipenuh', 'codrington', 'vardo', 'khromtau', 'port hardy', 'ijaki', 'barentsburg', 'dharchula', 'kurgunta', 'abnub', 'esterhazy', 'clyde river', 'attawapiskat', 'nemuro', 'bilma', 'goderich', 'pisco', 'belushya guba', 'chicama', 'koutsouras', 'paamiut', 'poum', 'ibra', 'bac lieu', 'burica', 'namibe', 'valdivia', 'samarai', 'wanning', 'wichita', 'rivera', 'pacific grove', 'husavik', 'manzhouli', 'zhongshu', 'yingzhong', 'azuaga', 'myitkyina', 'kutum', 'amberley', 'jackson', 'halalo', 'yeniseysk', 'marsa matruh', 'gerede', 'ilhabela', 'terrak', 'omsukchan', 'warqla', 'kulykivka', 'barcelos', 'saquarema', 'nago', 'soubre', 'helong', 'nizhneyansk', 'ancud', 'suntar ...
#
#
#  Leaving behind the duplicated cities, the count of cities =  606

# %% [markdown]
# *Creating a Dataframe of the generated Cities:*

# %%
cities_df = pd.DataFrame({'Cities' : cities})
cities_df.head()
# Out:
#         Cities
# 0    jamestown
# 1  piney green
# 2       barrow
# 3        vaini
# 4  mizpe ramon

# %% [markdown]
# *Writing cities to csv:*

# %%
cities_df.to_csv(r"python-api-challenge\Cities.csv", index=False, header=True)
print("File write successful")
# Out:
# File write successful

# %% [markdown]
# *Defining the required functions to update metrics*

# %%
def kelvin_to_farenheit(temps):
    """Converts a Kelvin temperature to Fahrenheit"""
    return temps * 9/5 - 459.67

def mps_to_mph(windSpeed):
    """Converts a meters/s speed to miles/hour"""
    return windSpeed * 2.23694

# %% [markdown]
# *Performing API Calls using each city in the openweather API url get the weather data*

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?q="
#Obtain weathercheck data for the cities from openweather map: 

city_name = cities
row = []
city_row = []
for i in range(len(city_name)):
#for i in range(10):
    print(f"Processing request for index number: {i} which is for City: {city_name[i]}")
    url = base_url + city_name[i] + "&appid=" + w_key
    print(url)
    response = requests.get(url)
    city_json = response.json()
    #print(city_json)
    print(response.status_code)
    if response.status_code == 200:
        try:
            city_cntry = (city_json['sys']['country'])
            #print(city_cntry)
            city_lat = (city_json['coord']['lat'])
            #print(city_lat)
            city_lon = (city_json['coord']['lon']) 
           # print(city_lon)
            city_temp = kelvin_to_farenheit(city_json['main']['temp'])
           # print(city_temp)
            city_humidity = (city_json['main']['humidity'])
            #print(city_humidity)
            city_cloudiness = (city_json['clouds']['all'])
           # print(city_cloudiness)
            city_windSpeed = mps_to_mph(city_json['wind']['speed'])
           # print(city_windSpeed)
            row = [city_name[i], city_cntry, city_lat, city_lon, city_temp, city_humidity, city_cloudiness, city_windSpeed]
           # print(row)
            city_row.append(row)
            #print(city_row)
        except:
            print(f"I skipped {cities[i]} because something isn't right")

city_df = pd.DataFrame(city_row)   
city_df.columns = ['City', 'Country', 'Lat', 'Lon', 'Temp', 'Humidity', 'Cloudiness', 'Windspeed']

city_df.head()
# Out:
# Processing request for index number: 0 which is for City: cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 1 which is for City: labuhan
# http://api.openweathermap.org/data/2.5/weather?q=labuhan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 2 which is for City: la ronge
# http://api.openweathermap.org/data/2.5/weather?q=la ronge&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 3 which is for City: rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 4 which is for City: olafsvik
# http://api.openweathermap.org/data/2.5/weather?q=olafsvik&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 5 which is for City: yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 6 which is for City: hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 7 which is for City: cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?q=cabo san lucas&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 8 which is for City: ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 9 which is for City: ewa beach
# http://api.openweathermap.org/data/2.5/weather?q=ewa beach&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 10 which is for City: clarksburg
# http://api.openweathermap.org/data/2.5/weather?q=clarksburg&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 11 which is for City: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 12 which is for City: rocha
# http://api.openweathermap.org/data/2.5/weather?q=rocha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 13 which is for City: ambanja
# http://api.openweathermap.org/data/2.5/weather?q=ambanja&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 14 which is for City: busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 15 which is for City: ponta do sol
# http://api.openweathermap.org/data/2.5/weather?q=ponta do sol&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 16 which is for City: coihaique
# http://api.openweathermap.org/data/2.5/weather?q=coihaique&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 17 which is for City: college
# http://api.openweathermap.org/data/2.5/weather?q=college&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 18 which is for City: fort nelson
# http://api.openweathermap.org/data/2.5/weather?q=fort nelson&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 19 which is for City: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 20 which is for City: asau
# http://api.openweathermap.org/data/2.5/weather?q=asau&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 21 which is for City: mrirt
# http://api.openweathermap.org/data/2.5/weather?q=mrirt&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 22 which is for City: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 23 which is for City: aljezur
# http://api.openweathermap.org/data/2.5/weather?q=aljezur&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 24 which is for City: sao filipe
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 25 which is for City: akyab
# http://api.openweathermap.org/data/2.5/weather?q=akyab&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 26 which is for City: apatity
# http://api.openweathermap.org/data/2.5/weather?q=apatity&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 27 which is for City: port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 28 which is for City: lansing
# http://api.openweathermap.org/data/2.5/weather?q=lansing&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 29 which is for City: otofuke
# http://api.openweathermap.org/data/2.5/weather?q=otofuke&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 30 which is for City: hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 31 which is for City: kavaratti
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 32 which is for City: punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 33 which is for City: victoria
# http://api.openweathermap.org/data/2.5/weather?q=victoria&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 34 which is for City: dali
# http://api.openweathermap.org/data/2.5/weather?q=dali&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 35 which is for City: dingle
# http://api.openweathermap.org/data/2.5/weather?q=dingle&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 36 which is for City: barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 37 which is for City: hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 38 which is for City: andra
# http://api.openweathermap.org/data/2.5/weather?q=andra&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 39 which is for City: laguna
# http://api.openweathermap.org/data/2.5/weather?q=laguna&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 40 which is for City: cedar city
# http://api.openweathermap.org/data/2.5/weather?q=cedar city&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 41 which is for City: castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 42 which is for City: upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 43 which is for City: donskoye
# http://api.openweathermap.org/data/2.5/weather?q=donskoye&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 44 which is for City: tahe
# http://api.openweathermap.org/data/2.5/weather?q=tahe&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 45 which is for City: rudnichnyy
# http://api.openweathermap.org/data/2.5/weather?q=rudnichnyy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 46 which is for City: butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 47 which is for City: padang
# http://api.openweathermap.org/data/2.5/weather?q=padang&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 48 which is for City: bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 49 which is for City: provideniya
# http://api.openweathermap.org/data/2.5/weather?q=provideniya&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 50 which is for City: illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 51 which is for City: vao
# http://api.openweathermap.org/data/2.5/weather?q=vao&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 52 which is for City: karamea
# http://api.openweathermap.org/data/2.5/weather?q=karamea&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 53 which is for City: freeport
# http://api.openweathermap.org/data/2.5/weather?q=freeport&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 54 which is for City: maxixe
# http://api.openweathermap.org/data/2.5/weather?q=maxixe&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 55 which is for City: lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 56 which is for City: arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 57 which is for City: vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 58 which is for City: coahuayana
# http://api.openweathermap.org/data/2.5/weather?q=coahuayana&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 59 which is for City: umm lajj
# http://api.openweathermap.org/data/2.5/weather?q=umm lajj&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 60 which is for City: dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 61 which is for City: matagami
# http://api.openweathermap.org/data/2.5/weather?q=matagami&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 62 which is for City: jamsa
# http://api.openweathermap.org/data/2.5/weather?q=jamsa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 63 which is for City: robertsport
# http://api.openweathermap.org/data/2.5/weather?q=robertsport&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 64 which is for City: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 65 which is for City: kamenskoye
# http://api.openweathermap.org/data/2.5/weather?q=kamenskoye&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 66 which is for City: longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 67 which is for City: general roca
# http://api.openweathermap.org/data/2.5/weather?q=general roca&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 68 which is for City: am timan
# http://api.openweathermap.org/data/2.5/weather?q=am timan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 69 which is for City: tilsonburg
# http://api.openweathermap.org/data/2.5/weather?q=tilsonburg&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 70 which is for City: kalaleh
# http://api.openweathermap.org/data/2.5/weather?q=kalaleh&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 71 which is for City: puchezh
# http://api.openweathermap.org/data/2.5/weather?q=puchezh&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 72 which is for City: ilebo
# http://api.openweathermap.org/data/2.5/weather?q=ilebo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 73 which is for City: port macquarie
# http://api.openweathermap.org/data/2.5/weather?q=port macquarie&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 74 which is for City: petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?q=petropavlovsk-kamchatskiy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 75 which is for City: iaciara
# http://api.openweathermap.org/data/2.5/weather?q=iaciara&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 76 which is for City: tiksi
# http://api.openweathermap.org/data/2.5/weather?q=tiksi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 77 which is for City: komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 78 which is for City: libreville
# http://api.openweathermap.org/data/2.5/weather?q=libreville&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 79 which is for City: salalah
# http://api.openweathermap.org/data/2.5/weather?q=salalah&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 80 which is for City: brae
# http://api.openweathermap.org/data/2.5/weather?q=brae&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 81 which is for City: port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 82 which is for City: norman wells
# http://api.openweathermap.org/data/2.5/weather?q=norman wells&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 83 which is for City: new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 84 which is for City: marystown
# http://api.openweathermap.org/data/2.5/weather?q=marystown&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 85 which is for City: marfino
# http://api.openweathermap.org/data/2.5/weather?q=marfino&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 86 which is for City: beroroha
# http://api.openweathermap.org/data/2.5/weather?q=beroroha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 87 which is for City: kristiinankaupunki
# http://api.openweathermap.org/data/2.5/weather?q=kristiinankaupunki&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 88 which is for City: meridian
# http://api.openweathermap.org/data/2.5/weather?q=meridian&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 89 which is for City: saleaula
# http://api.openweathermap.org/data/2.5/weather?q=saleaula&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 90 which is for City: taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 91 which is for City: jacareacanga
# http://api.openweathermap.org/data/2.5/weather?q=jacareacanga&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 92 which is for City: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 93 which is for City: severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 94 which is for City: ilulissat
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 95 which is for City: ahipara
# http://api.openweathermap.org/data/2.5/weather?q=ahipara&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 96 which is for City: tuatapere
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 97 which is for City: pevek
# http://api.openweathermap.org/data/2.5/weather?q=pevek&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 98 which is for City: nortelandia
# http://api.openweathermap.org/data/2.5/weather?q=nortelandia&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 99 which is for City: fukue
# http://api.openweathermap.org/data/2.5/weather?q=fukue&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 100 which is for City: albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 101 which is for City: souillac
# http://api.openweathermap.org/data/2.5/weather?q=souillac&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 102 which is for City: kavieng
# http://api.openweathermap.org/data/2.5/weather?q=kavieng&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 103 which is for City: carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 104 which is for City: mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 105 which is for City: vila
# http://api.openweathermap.org/data/2.5/weather?q=vila&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 106 which is for City: san luis
# http://api.openweathermap.org/data/2.5/weather?q=san luis&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 107 which is for City: jinxi
# http://api.openweathermap.org/data/2.5/weather?q=jinxi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 108 which is for City: henties bay
# http://api.openweathermap.org/data/2.5/weather?q=henties bay&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 109 which is for City: ternate
# http://api.openweathermap.org/data/2.5/weather?q=ternate&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 110 which is for City: ucluelet
# http://api.openweathermap.org/data/2.5/weather?q=ucluelet&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 111 which is for City: bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 112 which is for City: mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 113 which is for City: lyantonde
# http://api.openweathermap.org/data/2.5/weather?q=lyantonde&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 114 which is for City: bloomfield
# http://api.openweathermap.org/data/2.5/weather?q=bloomfield&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 115 which is for City: scottsbluff
# http://api.openweathermap.org/data/2.5/weather?q=scottsbluff&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 116 which is for City: grand river south east
# http://api.openweathermap.org/data/2.5/weather?q=grand river south east&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 117 which is for City: chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 118 which is for City: cockburn town
# http://api.openweathermap.org/data/2.5/weather?q=cockburn town&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 119 which is for City: la rioja
# http://api.openweathermap.org/data/2.5/weather?q=la rioja&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 120 which is for City: mayo
# http://api.openweathermap.org/data/2.5/weather?q=mayo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 121 which is for City: lower hutt
# http://api.openweathermap.org/data/2.5/weather?q=lower hutt&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 122 which is for City: cururupu
# http://api.openweathermap.org/data/2.5/weather?q=cururupu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 123 which is for City: khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 124 which is for City: east london
# http://api.openweathermap.org/data/2.5/weather?q=east london&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 125 which is for City: nioro
# http://api.openweathermap.org/data/2.5/weather?q=nioro&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 126 which is for City: neuquen
# http://api.openweathermap.org/data/2.5/weather?q=neuquen&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 127 which is for City: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 128 which is for City: tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 129 which is for City: cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 130 which is for City: casas grandes
# http://api.openweathermap.org/data/2.5/weather?q=casas grandes&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 131 which is for City: san jose
# http://api.openweathermap.org/data/2.5/weather?q=san jose&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 132 which is for City: koutiala
# http://api.openweathermap.org/data/2.5/weather?q=koutiala&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 133 which is for City: namatanai
# http://api.openweathermap.org/data/2.5/weather?q=namatanai&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 134 which is for City: chachapoyas
# http://api.openweathermap.org/data/2.5/weather?q=chachapoyas&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 135 which is for City: florence
# http://api.openweathermap.org/data/2.5/weather?q=florence&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 136 which is for City: aykhal
# http://api.openweathermap.org/data/2.5/weather?q=aykhal&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 137 which is for City: naze
# http://api.openweathermap.org/data/2.5/weather?q=naze&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 138 which is for City: taltal
# http://api.openweathermap.org/data/2.5/weather?q=taltal&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 139 which is for City: jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 140 which is for City: matli
# http://api.openweathermap.org/data/2.5/weather?q=matli&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 141 which is for City: avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 142 which is for City: riyadh
# http://api.openweathermap.org/data/2.5/weather?q=riyadh&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 143 which is for City: san rafael del sur
# http://api.openweathermap.org/data/2.5/weather?q=san rafael del sur&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 144 which is for City: faanui
# http://api.openweathermap.org/data/2.5/weather?q=faanui&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 145 which is for City: kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 146 which is for City: vanimo
# http://api.openweathermap.org/data/2.5/weather?q=vanimo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 147 which is for City: portland
# http://api.openweathermap.org/data/2.5/weather?q=portland&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 148 which is for City: grand gaube
# http://api.openweathermap.org/data/2.5/weather?q=grand gaube&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 149 which is for City: kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 150 which is for City: sehithwa
# http://api.openweathermap.org/data/2.5/weather?q=sehithwa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 151 which is for City: rancho palos verdes
# http://api.openweathermap.org/data/2.5/weather?q=rancho palos verdes&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 152 which is for City: manado
# http://api.openweathermap.org/data/2.5/weather?q=manado&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 153 which is for City: puerto boyaca
# http://api.openweathermap.org/data/2.5/weather?q=puerto boyaca&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 154 which is for City: aklavik
# http://api.openweathermap.org/data/2.5/weather?q=aklavik&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 155 which is for City: thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 156 which is for City: sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?q=sao jose da coroa grande&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 157 which is for City: hasaki
# http://api.openweathermap.org/data/2.5/weather?q=hasaki&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 158 which is for City: karratha
# http://api.openweathermap.org/data/2.5/weather?q=karratha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 159 which is for City: saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 160 which is for City: mitake
# http://api.openweathermap.org/data/2.5/weather?q=mitake&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 161 which is for City: darnah
# http://api.openweathermap.org/data/2.5/weather?q=darnah&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 162 which is for City: karlshus
# http://api.openweathermap.org/data/2.5/weather?q=karlshus&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 163 which is for City: esperance
# http://api.openweathermap.org/data/2.5/weather?q=esperance&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 164 which is for City: madimba
# http://api.openweathermap.org/data/2.5/weather?q=madimba&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 165 which is for City: bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 166 which is for City: sept-iles
# http://api.openweathermap.org/data/2.5/weather?q=sept-iles&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 167 which is for City: atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 168 which is for City: sibolga
# http://api.openweathermap.org/data/2.5/weather?q=sibolga&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 169 which is for City: port-cartier
# http://api.openweathermap.org/data/2.5/weather?q=port-cartier&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 170 which is for City: duluth
# http://api.openweathermap.org/data/2.5/weather?q=duluth&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 171 which is for City: pemangkat
# http://api.openweathermap.org/data/2.5/weather?q=pemangkat&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 172 which is for City: broken hill
# http://api.openweathermap.org/data/2.5/weather?q=broken hill&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 173 which is for City: miyako
# http://api.openweathermap.org/data/2.5/weather?q=miyako&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 174 which is for City: colares
# http://api.openweathermap.org/data/2.5/weather?q=colares&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 175 which is for City: khor
# http://api.openweathermap.org/data/2.5/weather?q=khor&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 176 which is for City: makakilo city
# http://api.openweathermap.org/data/2.5/weather?q=makakilo city&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 177 which is for City: nang rong
# http://api.openweathermap.org/data/2.5/weather?q=nang rong&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 178 which is for City: trinidad
# http://api.openweathermap.org/data/2.5/weather?q=trinidad&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 179 which is for City: ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?q=ugoofaaru&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 180 which is for City: sambava
# http://api.openweathermap.org/data/2.5/weather?q=sambava&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 181 which is for City: marsh harbour
# http://api.openweathermap.org/data/2.5/weather?q=marsh harbour&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 182 which is for City: necochea
# http://api.openweathermap.org/data/2.5/weather?q=necochea&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 183 which is for City: la palma
# http://api.openweathermap.org/data/2.5/weather?q=la palma&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 184 which is for City: torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 185 which is for City: les cayes
# http://api.openweathermap.org/data/2.5/weather?q=les cayes&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 186 which is for City: srandakan
# http://api.openweathermap.org/data/2.5/weather?q=srandakan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 187 which is for City: tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 188 which is for City: nome
# http://api.openweathermap.org/data/2.5/weather?q=nome&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 189 which is for City: bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 190 which is for City: ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 191 which is for City: rawson
# http://api.openweathermap.org/data/2.5/weather?q=rawson&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 192 which is for City: kalmar
# http://api.openweathermap.org/data/2.5/weather?q=kalmar&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 193 which is for City: port hedland
# http://api.openweathermap.org/data/2.5/weather?q=port hedland&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 194 which is for City: fort-shevchenko
# http://api.openweathermap.org/data/2.5/weather?q=fort-shevchenko&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 195 which is for City: constitucion
# http://api.openweathermap.org/data/2.5/weather?q=constitucion&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 196 which is for City: narsaq
# http://api.openweathermap.org/data/2.5/weather?q=narsaq&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 197 which is for City: araouane
# http://api.openweathermap.org/data/2.5/weather?q=araouane&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 198 which is for City: bolungarvik
# http://api.openweathermap.org/data/2.5/weather?q=bolungarvik&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 199 which is for City: high level
# http://api.openweathermap.org/data/2.5/weather?q=high level&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 200 which is for City: gondanglegi
# http://api.openweathermap.org/data/2.5/weather?q=gondanglegi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 201 which is for City: aksu
# http://api.openweathermap.org/data/2.5/weather?q=aksu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 202 which is for City: oussouye
# http://api.openweathermap.org/data/2.5/weather?q=oussouye&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 203 which is for City: caucaia
# http://api.openweathermap.org/data/2.5/weather?q=caucaia&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 204 which is for City: tessalit
# http://api.openweathermap.org/data/2.5/weather?q=tessalit&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 205 which is for City: esmeraldas
# http://api.openweathermap.org/data/2.5/weather?q=esmeraldas&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 206 which is for City: arica
# http://api.openweathermap.org/data/2.5/weather?q=arica&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 207 which is for City: isangel
# http://api.openweathermap.org/data/2.5/weather?q=isangel&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 208 which is for City: mount gambier
# http://api.openweathermap.org/data/2.5/weather?q=mount gambier&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 209 which is for City: mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 210 which is for City: giyon
# http://api.openweathermap.org/data/2.5/weather?q=giyon&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 211 which is for City: santa cruz
# http://api.openweathermap.org/data/2.5/weather?q=santa cruz&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 212 which is for City: etla
# http://api.openweathermap.org/data/2.5/weather?q=etla&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 213 which is for City: mount isa
# http://api.openweathermap.org/data/2.5/weather?q=mount isa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 214 which is for City: hay river
# http://api.openweathermap.org/data/2.5/weather?q=hay river&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 215 which is for City: imbituva
# http://api.openweathermap.org/data/2.5/weather?q=imbituva&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 216 which is for City: hailar
# http://api.openweathermap.org/data/2.5/weather?q=hailar&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 217 which is for City: takoradi
# http://api.openweathermap.org/data/2.5/weather?q=takoradi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 218 which is for City: xiongshi
# http://api.openweathermap.org/data/2.5/weather?q=xiongshi&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 219 which is for City: sorong
# http://api.openweathermap.org/data/2.5/weather?q=sorong&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 220 which is for City: port-gentil
# http://api.openweathermap.org/data/2.5/weather?q=port-gentil&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 221 which is for City: mayumba
# http://api.openweathermap.org/data/2.5/weather?q=mayumba&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 222 which is for City: avera
# http://api.openweathermap.org/data/2.5/weather?q=avera&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 223 which is for City: amderma
# http://api.openweathermap.org/data/2.5/weather?q=amderma&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 224 which is for City: port lincoln
# http://api.openweathermap.org/data/2.5/weather?q=port lincoln&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 225 which is for City: usinsk
# http://api.openweathermap.org/data/2.5/weather?q=usinsk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 226 which is for City: anadyr
# http://api.openweathermap.org/data/2.5/weather?q=anadyr&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 227 which is for City: fortuna
# http://api.openweathermap.org/data/2.5/weather?q=fortuna&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 228 which is for City: bonthe
# http://api.openweathermap.org/data/2.5/weather?q=bonthe&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 229 which is for City: fairbanks
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 230 which is for City: jiazi
# http://api.openweathermap.org/data/2.5/weather?q=jiazi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 231 which is for City: samusu
# http://api.openweathermap.org/data/2.5/weather?q=samusu&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 232 which is for City: havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?q=havre-saint-pierre&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 233 which is for City: khani
# http://api.openweathermap.org/data/2.5/weather?q=khani&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 234 which is for City: alta floresta
# http://api.openweathermap.org/data/2.5/weather?q=alta floresta&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 235 which is for City: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 236 which is for City: ghanzi
# http://api.openweathermap.org/data/2.5/weather?q=ghanzi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 237 which is for City: nanzhang
# http://api.openweathermap.org/data/2.5/weather?q=nanzhang&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 238 which is for City: bargal
# http://api.openweathermap.org/data/2.5/weather?q=bargal&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 239 which is for City: tiznit
# http://api.openweathermap.org/data/2.5/weather?q=tiznit&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 240 which is for City: bakau
# http://api.openweathermap.org/data/2.5/weather?q=bakau&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 241 which is for City: sisophon
# http://api.openweathermap.org/data/2.5/weather?q=sisophon&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 242 which is for City: port moresby
# http://api.openweathermap.org/data/2.5/weather?q=port moresby&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 243 which is for City: little elm
# http://api.openweathermap.org/data/2.5/weather?q=little elm&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 244 which is for City: abu samrah
# http://api.openweathermap.org/data/2.5/weather?q=abu samrah&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 245 which is for City: dickinson
# http://api.openweathermap.org/data/2.5/weather?q=dickinson&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 246 which is for City: danville
# http://api.openweathermap.org/data/2.5/weather?q=danville&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 247 which is for City: hermiston
# http://api.openweathermap.org/data/2.5/weather?q=hermiston&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 248 which is for City: luderitz
# http://api.openweathermap.org/data/2.5/weather?q=luderitz&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 249 which is for City: presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?q=presidencia roque saenz pena&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 250 which is for City: kashan
# http://api.openweathermap.org/data/2.5/weather?q=kashan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 251 which is for City: omboue
# http://api.openweathermap.org/data/2.5/weather?q=omboue&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 252 which is for City: bilibino
# http://api.openweathermap.org/data/2.5/weather?q=bilibino&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 253 which is for City: camacha
# http://api.openweathermap.org/data/2.5/weather?q=camacha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 254 which is for City: waingapu
# http://api.openweathermap.org/data/2.5/weather?q=waingapu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 255 which is for City: port blair
# http://api.openweathermap.org/data/2.5/weather?q=port blair&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 256 which is for City: nanortalik
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 257 which is for City: miri
# http://api.openweathermap.org/data/2.5/weather?q=miri&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 258 which is for City: aparecida
# http://api.openweathermap.org/data/2.5/weather?q=aparecida&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 259 which is for City: aflu
# http://api.openweathermap.org/data/2.5/weather?q=aflu&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 260 which is for City: hofn
# http://api.openweathermap.org/data/2.5/weather?q=hofn&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 261 which is for City: sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 262 which is for City: sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?q=sungaipenuh&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 263 which is for City: codrington
# http://api.openweathermap.org/data/2.5/weather?q=codrington&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 264 which is for City: vardo
# http://api.openweathermap.org/data/2.5/weather?q=vardo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 265 which is for City: khromtau
# http://api.openweathermap.org/data/2.5/weather?q=khromtau&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 266 which is for City: port hardy
# http://api.openweathermap.org/data/2.5/weather?q=port hardy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 267 which is for City: ijaki
# http://api.openweathermap.org/data/2.5/weather?q=ijaki&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 268 which is for City: barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 269 which is for City: dharchula
# http://api.openweathermap.org/data/2.5/weather?q=dharchula&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 270 which is for City: kurgunta
# http://api.openweathermap.org/data/2.5/weather?q=kurgunta&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 271 which is for City: abnub
# http://api.openweathermap.org/data/2.5/weather?q=abnub&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 272 which is for City: esterhazy
# http://api.openweathermap.org/data/2.5/weather?q=esterhazy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 273 which is for City: clyde river
# http://api.openweathermap.org/data/2.5/weather?q=clyde river&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 274 which is for City: attawapiskat
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 275 which is for City: nemuro
# http://api.openweathermap.org/data/2.5/weather?q=nemuro&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 276 which is for City: bilma
# http://api.openweathermap.org/data/2.5/weather?q=bilma&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 277 which is for City: goderich
# http://api.openweathermap.org/data/2.5/weather?q=goderich&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 278 which is for City: pisco
# http://api.openweathermap.org/data/2.5/weather?q=pisco&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 279 which is for City: belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 280 which is for City: chicama
# http://api.openweathermap.org/data/2.5/weather?q=chicama&appid=397b95f1b822905242cabd4b62006f61
# 200
# ...
# http://api.openweathermap.org/data/2.5/weather?q=moyale&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 516 which is for City: oistins
# http://api.openweathermap.org/data/2.5/weather?q=oistins&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 517 which is for City: kidal
# http://api.openweathermap.org/data/2.5/weather?q=kidal&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 518 which is for City: walvis bay
# http://api.openweathermap.org/data/2.5/weather?q=walvis bay&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 519 which is for City: elliot lake
# http://api.openweathermap.org/data/2.5/weather?q=elliot lake&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 520 which is for City: fershampenuaz
# http://api.openweathermap.org/data/2.5/weather?q=fershampenuaz&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 521 which is for City: assiniboia
# http://api.openweathermap.org/data/2.5/weather?q=assiniboia&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 522 which is for City: karaton
# http://api.openweathermap.org/data/2.5/weather?q=karaton&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 523 which is for City: lavrentiya
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 524 which is for City: linjiang
# http://api.openweathermap.org/data/2.5/weather?q=linjiang&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 525 which is for City: hirado
# http://api.openweathermap.org/data/2.5/weather?q=hirado&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 526 which is for City: oliver
# http://api.openweathermap.org/data/2.5/weather?q=oliver&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 527 which is for City: todos santos
# http://api.openweathermap.org/data/2.5/weather?q=todos santos&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 528 which is for City: tucurui
# http://api.openweathermap.org/data/2.5/weather?q=tucurui&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 529 which is for City: kenora
# http://api.openweathermap.org/data/2.5/weather?q=kenora&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 530 which is for City: santa luzia
# http://api.openweathermap.org/data/2.5/weather?q=santa luzia&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 531 which is for City: sterling
# http://api.openweathermap.org/data/2.5/weather?q=sterling&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 532 which is for City: manzanillo
# http://api.openweathermap.org/data/2.5/weather?q=manzanillo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 533 which is for City: ayr
# http://api.openweathermap.org/data/2.5/weather?q=ayr&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 534 which is for City: dubreka
# http://api.openweathermap.org/data/2.5/weather?q=dubreka&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 535 which is for City: charters towers
# http://api.openweathermap.org/data/2.5/weather?q=charters towers&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 536 which is for City: linares
# http://api.openweathermap.org/data/2.5/weather?q=linares&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 537 which is for City: cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 538 which is for City: atar
# http://api.openweathermap.org/data/2.5/weather?q=atar&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 539 which is for City: galle
# http://api.openweathermap.org/data/2.5/weather?q=galle&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 540 which is for City: kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?q=kysyl-syr&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 541 which is for City: inhambane
# http://api.openweathermap.org/data/2.5/weather?q=inhambane&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 542 which is for City: ryotsu
# http://api.openweathermap.org/data/2.5/weather?q=ryotsu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 543 which is for City: half moon bay
# http://api.openweathermap.org/data/2.5/weather?q=half moon bay&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 544 which is for City: mbandaka
# http://api.openweathermap.org/data/2.5/weather?q=mbandaka&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 545 which is for City: pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 546 which is for City: chara
# http://api.openweathermap.org/data/2.5/weather?q=chara&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 547 which is for City: quattro castella
# http://api.openweathermap.org/data/2.5/weather?q=quattro castella&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 548 which is for City: urdzhar
# http://api.openweathermap.org/data/2.5/weather?q=urdzhar&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 549 which is for City: sterlitamak
# http://api.openweathermap.org/data/2.5/weather?q=sterlitamak&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 550 which is for City: maragogi
# http://api.openweathermap.org/data/2.5/weather?q=maragogi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 551 which is for City: envira
# http://api.openweathermap.org/data/2.5/weather?q=envira&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 552 which is for City: garmsar
# http://api.openweathermap.org/data/2.5/weather?q=garmsar&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 553 which is for City: biak
# http://api.openweathermap.org/data/2.5/weather?q=biak&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 554 which is for City: jollyville
# http://api.openweathermap.org/data/2.5/weather?q=jollyville&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 555 which is for City: nainpur
# http://api.openweathermap.org/data/2.5/weather?q=nainpur&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 556 which is for City: boueni
# http://api.openweathermap.org/data/2.5/weather?q=boueni&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 557 which is for City: piacabucu
# http://api.openweathermap.org/data/2.5/weather?q=piacabucu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 558 which is for City: tazovskiy
# http://api.openweathermap.org/data/2.5/weather?q=tazovskiy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 559 which is for City: nyurba
# http://api.openweathermap.org/data/2.5/weather?q=nyurba&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 560 which is for City: salvador
# http://api.openweathermap.org/data/2.5/weather?q=salvador&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 561 which is for City: iqaluit
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 562 which is for City: alofi
# http://api.openweathermap.org/data/2.5/weather?q=alofi&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 563 which is for City: karaul
# http://api.openweathermap.org/data/2.5/weather?q=karaul&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 564 which is for City: sola
# http://api.openweathermap.org/data/2.5/weather?q=sola&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 565 which is for City: rundu
# http://api.openweathermap.org/data/2.5/weather?q=rundu&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 566 which is for City: sataua
# http://api.openweathermap.org/data/2.5/weather?q=sataua&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 567 which is for City: pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?q=pangkalanbuun&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 568 which is for City: lewistown
# http://api.openweathermap.org/data/2.5/weather?q=lewistown&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 569 which is for City: shenkursk
# http://api.openweathermap.org/data/2.5/weather?q=shenkursk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 570 which is for City: mangan
# http://api.openweathermap.org/data/2.5/weather?q=mangan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 571 which is for City: guerrero negro
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 572 which is for City: chaihe
# http://api.openweathermap.org/data/2.5/weather?q=chaihe&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 573 which is for City: trail
# http://api.openweathermap.org/data/2.5/weather?q=trail&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 574 which is for City: vrangel
# http://api.openweathermap.org/data/2.5/weather?q=vrangel&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 575 which is for City: yeppoon
# http://api.openweathermap.org/data/2.5/weather?q=yeppoon&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 576 which is for City: inirida
# http://api.openweathermap.org/data/2.5/weather?q=inirida&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 577 which is for City: vangaindrano
# http://api.openweathermap.org/data/2.5/weather?q=vangaindrano&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 578 which is for City: senador jose porfirio
# http://api.openweathermap.org/data/2.5/weather?q=senador jose porfirio&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 579 which is for City: artvin
# http://api.openweathermap.org/data/2.5/weather?q=artvin&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 580 which is for City: rio grande
# http://api.openweathermap.org/data/2.5/weather?q=rio grande&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 581 which is for City: gazalkent
# http://api.openweathermap.org/data/2.5/weather?q=gazalkent&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 582 which is for City: hirara
# http://api.openweathermap.org/data/2.5/weather?q=hirara&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 583 which is for City: wangqing
# http://api.openweathermap.org/data/2.5/weather?q=wangqing&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 584 which is for City: gazanjyk
# http://api.openweathermap.org/data/2.5/weather?q=gazanjyk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 585 which is for City: sirjan
# http://api.openweathermap.org/data/2.5/weather?q=sirjan&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 586 which is for City: puerto rondon
# http://api.openweathermap.org/data/2.5/weather?q=puerto rondon&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 587 which is for City: antofagasta
# http://api.openweathermap.org/data/2.5/weather?q=antofagasta&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 588 which is for City: ayer itam
# http://api.openweathermap.org/data/2.5/weather?q=ayer itam&appid=397b95f1b822905242cabd4b62006f61
# 404
# Processing request for index number: 589 which is for City: svecha
# http://api.openweathermap.org/data/2.5/weather?q=svecha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 590 which is for City: santa isabel
# http://api.openweathermap.org/data/2.5/weather?q=santa isabel&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 591 which is for City: alice springs
# http://api.openweathermap.org/data/2.5/weather?q=alice springs&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 592 which is for City: puerto escondido
# http://api.openweathermap.org/data/2.5/weather?q=puerto escondido&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 593 which is for City: leningradskiy
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 594 which is for City: kovdor
# http://api.openweathermap.org/data/2.5/weather?q=kovdor&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 595 which is for City: urubicha
# http://api.openweathermap.org/data/2.5/weather?q=urubicha&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 596 which is for City: comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?q=comodoro rivadavia&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 597 which is for City: kumbo
# http://api.openweathermap.org/data/2.5/weather?q=kumbo&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 598 which is for City: bad sachsa
# http://api.openweathermap.org/data/2.5/weather?q=bad sachsa&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 599 which is for City: rybinsk
# http://api.openweathermap.org/data/2.5/weather?q=rybinsk&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 600 which is for City: afua
# http://api.openweathermap.org/data/2.5/weather?q=afua&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 601 which is for City: mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?q=mitsamiouli&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 602 which is for City: asadabad
# http://api.openweathermap.org/data/2.5/weather?q=asadabad&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 603 which is for City: visnes
# http://api.openweathermap.org/data/2.5/weather?q=visnes&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 604 which is for City: shahreza
# http://api.openweathermap.org/data/2.5/weather?q=shahreza&appid=397b95f1b822905242cabd4b62006f61
# 200
# Processing request for index number: 605 which is for City: hualmay
# http://api.openweathermap.org/data/2.5/weather?q=hualmay&appid=397b95f1b822905242cabd4b62006f61
# 200
#         City Country    Lat     Lon    Temp  Humidity  Cloudiness  Windspeed
# 0  cape town      ZA -33.93   18.42  54.266        76           0   4.697574
# 1    labuhan      ID  -6.88  112.21  80.258        80          11   5.927891
# 2   la ronge      CA  55.10 -105.28  26.600        58          90   2.236940
# 3    rikitea      PF -23.12 -134.97  73.598        79           0  14.651957
# 4   olafsvik      IS  64.89  -23.71  42.476        86         100  14.249308

# %% [markdown]
# *Create a DataFrame of the weathercheck data*

# %%
weather_check_df = pd.DataFrame({ "City" : city_df['City'],
                                  "Latitude" : city_df['Lat'],
                                  "Longitude" : city_df['Lon'],
                                  "Temperature(F)" : city_df['Temp'],
                                  "Humidity%" : city_df['Humidity'],
                                  "Cloudiness%" : city_df['Cloudiness'],
                                  "Wind Speed(mph)" : city_df['Windspeed'] })                                                         

weather_check_df.head()
# Out:
#         City  Latitude  Longitude  Temperature(F)  Humidity%  Cloudiness%  \
# 0  cape town    -33.93      18.42          54.266         76            0
# 1    labuhan     -6.88     112.21          80.258         80           11
# 2   la ronge     55.10    -105.28          26.600         58           90
# 3    rikitea    -23.12    -134.97          73.598         79            0
# 4   olafsvik     64.89     -23.71          42.476         86          100
#
#    Wind Speed(mph)
# 0         4.697574
# 1         5.927891
# 2         2.236940
# 3        14.651957
# 4        14.249308

# %% [markdown]
# *Definining a function called 'scatter_plot' for plotting the visualization*

# %%
def scatter_plot(x_values,y_values,x_label,y_label,title,regress):
    plt.scatter(x_values,y_values,marker="o", facecolors="red", edgecolors="black",s=30, alpha=0.75)
    if regress==True:
        (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
        regress_values = x_values * slope + intercept
        line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
        r_sq = "r-sq="+str(round(rvalue,2))
        plt.plot(x_values,regress_values,"r-")
        
        x_location=round(np.percentile(x_values,50),0)
        y_location=round(np.percentile(regress_values,50),0)
               
        plt.annotate(line_eq, (x_location,y_location), fontsize=12,color="green")
        plt.annotate(r_sq, (x_location,y_location-10), fontsize=12,color="green")
    
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# %% [markdown]
# *Definining a function called 'save_image'*

# %%
def save_image(x_values,y_values,x_label,y_label,title, regress):
    scatter_plot(x_values,y_values,x_label,y_label,title,regress)
    plt.savefig(f"python-api-challenge\{title}.png")
    plt.show()

# %%
#Defining a list of weather data to be x - values & regions for plotting latitude vs weather data
weather_info = ['Temperature(F)', 'Humidity%', 'Cloudiness%', 'Wind Speed(mph)']
regress=False
for info in weather_info:
    print(f"Plotting & saving the scatter chart of {info} vs. Latitude")
    x_values = weather_check_df[info]
    y_values = weather_check_df['Latitude']
    x_label = info
    y_label = "Latitude (degrees)"
    title = f"{info}_vs_Latitude"
    save_image(x_values,y_values,x_label,y_label,title,regress)
# Out:
# Plotting & saving the scatter chart of Temperature(F) vs. Latitude
# Plotting & saving the scatter chart of Humidity% vs. Latitude
# Plotting & saving the scatter chart of Cloudiness% vs. Latitude
# Plotting & saving the scatter chart of Wind Speed(mph) vs. Latitude

# %%
# We need northern_hemisphere_weather_df and southern_hemisphere_weather_df out of weather_check_df
northern_hemisphere_weather_df = weather_check_df[weather_check_df['Latitude'] >= 0]
southern_hemisphere_weather_df = weather_check_df[weather_check_df['Latitude'] < 0]

#This block will call the function scatter_plot and provide parameters as defined below
regions = ['Northern_Hemisphere','Southern_Hemisphere']
#Defining a list of weather data to be x - values & regions for plotting
weather_info = ['Temperature(F)', 'Humidity%', 'Cloudiness%', 'Wind Speed(mph)']
#print overall parameters vs latitude without regression
regress=True
for region in regions:
    for info in weather_info:
        if region == 'Northern_Hemisphere':
            print(f"Plotting & saving the scatter chart of {region} - {info} vs. Latitude")
            weather_data_df = northern_hemisphere_weather_df
        elif region == 'Southern_Hemisphere':
            print(f"Plotting & saving the scatter chart of {region} - {info} vs. Latitude")
            weather_data_df = southern_hemisphere_weather_df  
        x_values = weather_data_df[info]
        y_values = weather_data_df['Latitude']
        x_label = info
        y_label = "Latitude (degrees)"
        title = f"{region} - {info}_vs_Latitude"
        save_image(x_values,y_values,x_label,y_label,title,regress)
# Out:
# Plotting & saving the scatter chart of Northern_Hemisphere - Temperature(F) vs. Latitude
# Plotting & saving the scatter chart of Northern_Hemisphere - Humidity% vs. Latitude
# Plotting & saving the scatter chart of Northern_Hemisphere - Cloudiness% vs. Latitude
# Plotting & saving the scatter chart of Northern_Hemisphere - Wind Speed(mph) vs. Latitude
# Plotting & saving the scatter chart of Southern_Hemisphere - Temperature(F) vs. Latitude
# Plotting & saving the scatter chart of Southern_Hemisphere - Humidity% vs. Latitude
# Plotting & saving the scatter chart of Southern_Hemisphere - Cloudiness% vs. Latitude
# Plotting & saving the scatter chart of Southern_Hemisphere - Wind Speed(mph) vs. Latitude

# %% [markdown]
# '''
# Inferences from the Graphs:
# Temperature has strong correlation the latitude of a city.
# There is strong positive correlation in Southern hemisphere(when the latitude increases, the temperature also increases and vice versa),
# and strong negative correlation(as latitude increases, temperature decreases and vice versa) in the Northern hemisphere.
#
# There is no indication of any correlation between humidity OR cloudiness with the latitude of a city.
#
# Also, there is no significant correlation between wind speed and latitude, but wind speed
# appears to be a constant in the cities belonging in the northern hemisphere.
# '''
