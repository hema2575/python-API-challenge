# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from pprint import pprint
import os
import csv
import gmaps
from config import g_key
from config1 import w_key
from citipy import citipy
print(g_key)
print(w_key)
# Out:
# AIzaSyA-MmN8Y965uvvQICNfhQEUUsKDRlp22uc
# 397b95f1b822905242cabd4b62006f61

# %%
#Reading the CSV file created in the part 1 of homework
cities = pd.read_csv(r"python-api-challenge\Cities.csv")
cities.head()
city_name = cities['Cities']
city_name
len(city_name)
# Out:
# 627

# %%
#Defining the required functions to update metrics
def kelvin_to_farenheit(temps):
    """Converts a Kelvin temperature to Fahrenheit"""
    return temps * 9/5 - 459.67

def mps_to_mph(windSpeed):
    """Converts a meters/s speed to miles/hour"""
    return windSpeed * 2.23694

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?q="
#Obtain weathercheck data for the cities from openweather map: 
row = []
city_row = []
for i in range(len(city_name)):
#for i in range(5):
    print(f"Processing request for index number: {i} which is for City: {city_name[i]}")
    url = base_url + city_name[i] + "&appid=" + w_key
    print(url)
    response = requests.get(url)
    city_json = response.json()
    #pprint(city_json)
    if response.status_code == 200:
        try:
            city_cntry = (city_json['sys']['country'])
            city_lat = (city_json['coord']['lat'])
            city_lon = (city_json['coord']['lon']) 
            city_tempmax = kelvin_to_farenheit((city_json['main']['temp_max']))
            city_humidity = (city_json['main']['humidity'])
            city_cloudiness = (city_json['clouds']['all'])
            city_windSpeed = mps_to_mph((city_json['wind']['speed']))  
            row = [city_name[i], city_cntry, city_lat, city_lon, city_tempmax, city_humidity, city_cloudiness, city_windSpeed]
            city_row.append(row)
        except:
            print(f"I skipped {cities[i]} because something isn't right")
#print(city_row)
city_df = pd.DataFrame(city_row)   
city_df.columns = ['City', 'Country', 'Lat', 'Lon', 'MaxTemp', 'Humidity', 'Cloudiness', 'Windspeed']

city_df
# Out:
# Processing request for index number: 0 which is for City: jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 1 which is for City: piney green
# http://api.openweathermap.org/data/2.5/weather?q=piney green&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 2 which is for City: barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 3 which is for City: vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 4 which is for City: mizpe ramon
# http://api.openweathermap.org/data/2.5/weather?q=mizpe ramon&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 5 which is for City: basco
# http://api.openweathermap.org/data/2.5/weather?q=basco&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 6 which is for City: korgen
# http://api.openweathermap.org/data/2.5/weather?q=korgen&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 7 which is for City: dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 8 which is for City: yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 9 which is for City: saint george
# http://api.openweathermap.org/data/2.5/weather?q=saint george&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 10 which is for City: dinsor
# http://api.openweathermap.org/data/2.5/weather?q=dinsor&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 11 which is for City: butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 12 which is for City: klaksvik
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 13 which is for City: chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 14 which is for City: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 15 which is for City: kuah
# http://api.openweathermap.org/data/2.5/weather?q=kuah&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 16 which is for City: vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?q=vysokogornyy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 17 which is for City: hay river
# http://api.openweathermap.org/data/2.5/weather?q=hay river&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 18 which is for City: parkersburg
# http://api.openweathermap.org/data/2.5/weather?q=parkersburg&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 19 which is for City: kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 20 which is for City: punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 21 which is for City: mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 22 which is for City: bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 23 which is for City: san quintin
# http://api.openweathermap.org/data/2.5/weather?q=san quintin&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 24 which is for City: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 25 which is for City: rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 26 which is for City: kjollefjord
# http://api.openweathermap.org/data/2.5/weather?q=kjollefjord&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 27 which is for City: sioux lookout
# http://api.openweathermap.org/data/2.5/weather?q=sioux lookout&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 28 which is for City: taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 29 which is for City: vaitupu
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 30 which is for City: norman wells
# http://api.openweathermap.org/data/2.5/weather?q=norman wells&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 31 which is for City: qurayyat
# http://api.openweathermap.org/data/2.5/weather?q=qurayyat&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 32 which is for City: torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 33 which is for City: ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 34 which is for City: ilulissat
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 35 which is for City: kamenskoye
# http://api.openweathermap.org/data/2.5/weather?q=kamenskoye&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 36 which is for City: saleaula
# http://api.openweathermap.org/data/2.5/weather?q=saleaula&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 37 which is for City: ust-kulom
# http://api.openweathermap.org/data/2.5/weather?q=ust-kulom&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 38 which is for City: tamandare
# http://api.openweathermap.org/data/2.5/weather?q=tamandare&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 39 which is for City: atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 40 which is for City: albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 41 which is for City: marzuq
# http://api.openweathermap.org/data/2.5/weather?q=marzuq&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 42 which is for City: georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 43 which is for City: santa marta
# http://api.openweathermap.org/data/2.5/weather?q=santa marta&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 44 which is for City: belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 45 which is for City: berezovyy
# http://api.openweathermap.org/data/2.5/weather?q=berezovyy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 46 which is for City: balabac
# http://api.openweathermap.org/data/2.5/weather?q=balabac&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 47 which is for City: illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 48 which is for City: namibe
# http://api.openweathermap.org/data/2.5/weather?q=namibe&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 49 which is for City: carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 50 which is for City: gat
# http://api.openweathermap.org/data/2.5/weather?q=gat&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 51 which is for City: biltine
# http://api.openweathermap.org/data/2.5/weather?q=biltine&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 52 which is for City: new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 53 which is for City: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 54 which is for City: minggang
# http://api.openweathermap.org/data/2.5/weather?q=minggang&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 55 which is for City: husavik
# http://api.openweathermap.org/data/2.5/weather?q=husavik&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 56 which is for City: avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 57 which is for City: coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 58 which is for City: mogadishu
# http://api.openweathermap.org/data/2.5/weather?q=mogadishu&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 59 which is for City: thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 60 which is for City: arman
# http://api.openweathermap.org/data/2.5/weather?q=arman&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 61 which is for City: pacific grove
# http://api.openweathermap.org/data/2.5/weather?q=pacific grove&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 62 which is for City: kahului
# http://api.openweathermap.org/data/2.5/weather?q=kahului&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 63 which is for City: borovskoy
# http://api.openweathermap.org/data/2.5/weather?q=borovskoy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 64 which is for City: hami
# http://api.openweathermap.org/data/2.5/weather?q=hami&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 65 which is for City: beringovskiy
# http://api.openweathermap.org/data/2.5/weather?q=beringovskiy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 66 which is for City: port hedland
# http://api.openweathermap.org/data/2.5/weather?q=port hedland&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 67 which is for City: hobyo
# http://api.openweathermap.org/data/2.5/weather?q=hobyo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 68 which is for City: kutum
# http://api.openweathermap.org/data/2.5/weather?q=kutum&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 69 which is for City: puerto colombia
# http://api.openweathermap.org/data/2.5/weather?q=puerto colombia&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 70 which is for City: brae
# http://api.openweathermap.org/data/2.5/weather?q=brae&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 71 which is for City: tiksi
# http://api.openweathermap.org/data/2.5/weather?q=tiksi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 72 which is for City: ha tinh
# http://api.openweathermap.org/data/2.5/weather?q=ha tinh&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 73 which is for City: srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?q=srednekolymsk&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 74 which is for City: hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 75 which is for City: sarka ghat
# http://api.openweathermap.org/data/2.5/weather?q=sarka ghat&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 76 which is for City: busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 77 which is for City: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 78 which is for City: arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 79 which is for City: brownsville
# http://api.openweathermap.org/data/2.5/weather?q=brownsville&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 80 which is for City: tilichiki
# http://api.openweathermap.org/data/2.5/weather?q=tilichiki&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 81 which is for City: dera ghazi khan
# http://api.openweathermap.org/data/2.5/weather?q=dera ghazi khan&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 82 which is for City: walvis bay
# http://api.openweathermap.org/data/2.5/weather?q=walvis bay&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 83 which is for City: zambezi
# http://api.openweathermap.org/data/2.5/weather?q=zambezi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 84 which is for City: nemuro
# http://api.openweathermap.org/data/2.5/weather?q=nemuro&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 85 which is for City: chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 86 which is for City: praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?q=praia da vitoria&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 87 which is for City: nuevo progreso
# http://api.openweathermap.org/data/2.5/weather?q=nuevo progreso&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 88 which is for City: port lincoln
# http://api.openweathermap.org/data/2.5/weather?q=port lincoln&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 89 which is for City: esperance
# http://api.openweathermap.org/data/2.5/weather?q=esperance&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 90 which is for City: sao filipe
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 91 which is for City: mbanza-ngungu
# http://api.openweathermap.org/data/2.5/weather?q=mbanza-ngungu&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 92 which is for City: bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 93 which is for City: yatou
# http://api.openweathermap.org/data/2.5/weather?q=yatou&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 94 which is for City: kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 95 which is for City: santona
# http://api.openweathermap.org/data/2.5/weather?q=santona&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 96 which is for City: kawalu
# http://api.openweathermap.org/data/2.5/weather?q=kawalu&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 97 which is for City: ambon
# http://api.openweathermap.org/data/2.5/weather?q=ambon&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 98 which is for City: tashtyp
# http://api.openweathermap.org/data/2.5/weather?q=tashtyp&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 99 which is for City: cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 100 which is for City: magadan
# http://api.openweathermap.org/data/2.5/weather?q=magadan&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 101 which is for City: sorvag
# http://api.openweathermap.org/data/2.5/weather?q=sorvag&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 102 which is for City: atar
# http://api.openweathermap.org/data/2.5/weather?q=atar&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 103 which is for City: caucaia
# http://api.openweathermap.org/data/2.5/weather?q=caucaia&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 104 which is for City: miyako
# http://api.openweathermap.org/data/2.5/weather?q=miyako&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 105 which is for City: krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?q=krasnoselkup&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 106 which is for City: jackson
# http://api.openweathermap.org/data/2.5/weather?q=jackson&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 107 which is for City: haines junction
# http://api.openweathermap.org/data/2.5/weather?q=haines junction&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 108 which is for City: acandi
# http://api.openweathermap.org/data/2.5/weather?q=acandi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 109 which is for City: sabang
# http://api.openweathermap.org/data/2.5/weather?q=sabang&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 110 which is for City: rorvik
# http://api.openweathermap.org/data/2.5/weather?q=rorvik&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 111 which is for City: ouahigouya
# http://api.openweathermap.org/data/2.5/weather?q=ouahigouya&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 112 which is for City: apache junction
# http://api.openweathermap.org/data/2.5/weather?q=apache junction&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 113 which is for City: khyriv
# http://api.openweathermap.org/data/2.5/weather?q=khyriv&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 114 which is for City: qaqortoq
# http://api.openweathermap.org/data/2.5/weather?q=qaqortoq&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 115 which is for City: karratha
# http://api.openweathermap.org/data/2.5/weather?q=karratha&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 116 which is for City: ozgon
# http://api.openweathermap.org/data/2.5/weather?q=ozgon&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 117 which is for City: aksu
# http://api.openweathermap.org/data/2.5/weather?q=aksu&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 118 which is for City: roebourne
# http://api.openweathermap.org/data/2.5/weather?q=roebourne&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 119 which is for City: lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 120 which is for City: nome
# http://api.openweathermap.org/data/2.5/weather?q=nome&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 121 which is for City: jega
# http://api.openweathermap.org/data/2.5/weather?q=jega&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 122 which is for City: findlay
# http://api.openweathermap.org/data/2.5/weather?q=findlay&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 123 which is for City: venado
# http://api.openweathermap.org/data/2.5/weather?q=venado&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 124 which is for City: bijie
# http://api.openweathermap.org/data/2.5/weather?q=bijie&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 125 which is for City: thunder bay
# http://api.openweathermap.org/data/2.5/weather?q=thunder bay&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 126 which is for City: port hardy
# http://api.openweathermap.org/data/2.5/weather?q=port hardy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 127 which is for City: yar-sale
# http://api.openweathermap.org/data/2.5/weather?q=yar-sale&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 128 which is for City: cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 129 which is for City: poum
# http://api.openweathermap.org/data/2.5/weather?q=poum&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 130 which is for City: longkou
# http://api.openweathermap.org/data/2.5/weather?q=longkou&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 131 which is for City: barbosa ferraz
# http://api.openweathermap.org/data/2.5/weather?q=barbosa ferraz&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 132 which is for City: dingle
# http://api.openweathermap.org/data/2.5/weather?q=dingle&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 133 which is for City: atherton
# http://api.openweathermap.org/data/2.5/weather?q=atherton&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 134 which is for City: vanimo
# http://api.openweathermap.org/data/2.5/weather?q=vanimo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 135 which is for City: kalmunai
# http://api.openweathermap.org/data/2.5/weather?q=kalmunai&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 136 which is for City: mehamn
# http://api.openweathermap.org/data/2.5/weather?q=mehamn&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 137 which is for City: hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 138 which is for City: porto murtinho
# http://api.openweathermap.org/data/2.5/weather?q=porto murtinho&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 139 which is for City: mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 140 which is for City: grand centre
# http://api.openweathermap.org/data/2.5/weather?q=grand centre&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 141 which is for City: sataua
# http://api.openweathermap.org/data/2.5/weather?q=sataua&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 142 which is for City: ucluelet
# http://api.openweathermap.org/data/2.5/weather?q=ucluelet&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 143 which is for City: razdolnoye
# http://api.openweathermap.org/data/2.5/weather?q=razdolnoye&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 144 which is for City: bubaque
# http://api.openweathermap.org/data/2.5/weather?q=bubaque&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 145 which is for City: petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?q=petropavlovsk-kamchatskiy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 146 which is for City: castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 147 which is for City: yulara
# http://api.openweathermap.org/data/2.5/weather?q=yulara&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 148 which is for City: geraldton
# http://api.openweathermap.org/data/2.5/weather?q=geraldton&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 149 which is for City: roald
# http://api.openweathermap.org/data/2.5/weather?q=roald&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 150 which is for City: ancud
# http://api.openweathermap.org/data/2.5/weather?q=ancud&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 151 which is for City: vangaindrano
# http://api.openweathermap.org/data/2.5/weather?q=vangaindrano&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 152 which is for City: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 153 which is for City: naze
# http://api.openweathermap.org/data/2.5/weather?q=naze&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 154 which is for City: sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 155 which is for City: barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 156 which is for City: kavieng
# http://api.openweathermap.org/data/2.5/weather?q=kavieng&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 157 which is for City: leningradskiy
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 158 which is for City: vardo
# http://api.openweathermap.org/data/2.5/weather?q=vardo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 159 which is for City: macon
# http://api.openweathermap.org/data/2.5/weather?q=macon&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 160 which is for City: poso
# http://api.openweathermap.org/data/2.5/weather?q=poso&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 161 which is for City: ajdabiya
# http://api.openweathermap.org/data/2.5/weather?q=ajdabiya&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 162 which is for City: necochea
# http://api.openweathermap.org/data/2.5/weather?q=necochea&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 163 which is for City: visby
# http://api.openweathermap.org/data/2.5/weather?q=visby&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 164 which is for City: buraydah
# http://api.openweathermap.org/data/2.5/weather?q=buraydah&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 165 which is for City: serrinha
# http://api.openweathermap.org/data/2.5/weather?q=serrinha&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 166 which is for City: tucuman
# http://api.openweathermap.org/data/2.5/weather?q=tucuman&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 167 which is for City: east london
# http://api.openweathermap.org/data/2.5/weather?q=east london&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 168 which is for City: khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 169 which is for City: morehead
# http://api.openweathermap.org/data/2.5/weather?q=morehead&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 170 which is for City: djambala
# http://api.openweathermap.org/data/2.5/weather?q=djambala&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 171 which is for City: havelock
# http://api.openweathermap.org/data/2.5/weather?q=havelock&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 172 which is for City: stornoway
# http://api.openweathermap.org/data/2.5/weather?q=stornoway&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 173 which is for City: bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 174 which is for City: moose factory
# http://api.openweathermap.org/data/2.5/weather?q=moose factory&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 175 which is for City: lata
# http://api.openweathermap.org/data/2.5/weather?q=lata&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 176 which is for City: port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 177 which is for City: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 178 which is for City: khandagayty
# http://api.openweathermap.org/data/2.5/weather?q=khandagayty&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 179 which is for City: chissamba
# http://api.openweathermap.org/data/2.5/weather?q=chissamba&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 180 which is for City: nyurba
# http://api.openweathermap.org/data/2.5/weather?q=nyurba&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 181 which is for City: kieta
# http://api.openweathermap.org/data/2.5/weather?q=kieta&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 182 which is for City: souillac
# http://api.openweathermap.org/data/2.5/weather?q=souillac&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 183 which is for City: panacan
# http://api.openweathermap.org/data/2.5/weather?q=panacan&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 184 which is for City: pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 185 which is for City: kavaratti
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 186 which is for City: christchurch
# http://api.openweathermap.org/data/2.5/weather?q=christchurch&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 187 which is for City: airai
# http://api.openweathermap.org/data/2.5/weather?q=airai&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 188 which is for City: thinadhoo
# http://api.openweathermap.org/data/2.5/weather?q=thinadhoo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 189 which is for City: nantucket
# http://api.openweathermap.org/data/2.5/weather?q=nantucket&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 190 which is for City: belmonte
# http://api.openweathermap.org/data/2.5/weather?q=belmonte&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 191 which is for City: marsh harbour
# http://api.openweathermap.org/data/2.5/weather?q=marsh harbour&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 192 which is for City: odweyne
# http://api.openweathermap.org/data/2.5/weather?q=odweyne&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 193 which is for City: pimentel
# http://api.openweathermap.org/data/2.5/weather?q=pimentel&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 194 which is for City: matamoros
# http://api.openweathermap.org/data/2.5/weather?q=matamoros&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 195 which is for City: bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 196 which is for City: broken hill
# http://api.openweathermap.org/data/2.5/weather?q=broken hill&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 197 which is for City: la seyne-sur-mer
# http://api.openweathermap.org/data/2.5/weather?q=la seyne-sur-mer&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 198 which is for City: awbari
# http://api.openweathermap.org/data/2.5/weather?q=awbari&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 199 which is for City: saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 200 which is for City: asau
# http://api.openweathermap.org/data/2.5/weather?q=asau&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 201 which is for City: bayan
# http://api.openweathermap.org/data/2.5/weather?q=bayan&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 202 which is for City: victor harbor
# http://api.openweathermap.org/data/2.5/weather?q=victor harbor&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 203 which is for City: henties bay
# http://api.openweathermap.org/data/2.5/weather?q=henties bay&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 204 which is for City: burns lake
# http://api.openweathermap.org/data/2.5/weather?q=burns lake&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 205 which is for City: nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 206 which is for City: port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 207 which is for City: port-gentil
# http://api.openweathermap.org/data/2.5/weather?q=port-gentil&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 208 which is for City: kruisfontein
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 209 which is for City: sharan
# http://api.openweathermap.org/data/2.5/weather?q=sharan&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 210 which is for City: fortuna
# http://api.openweathermap.org/data/2.5/weather?q=fortuna&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 211 which is for City: slave lake
# http://api.openweathermap.org/data/2.5/weather?q=slave lake&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 212 which is for City: amderma
# http://api.openweathermap.org/data/2.5/weather?q=amderma&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 213 which is for City: puerto leguizamo
# http://api.openweathermap.org/data/2.5/weather?q=puerto leguizamo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 214 which is for City: cap malheureux
# http://api.openweathermap.org/data/2.5/weather?q=cap malheureux&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 215 which is for City: marawi
# http://api.openweathermap.org/data/2.5/weather?q=marawi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 216 which is for City: thohoyandou
# http://api.openweathermap.org/data/2.5/weather?q=thohoyandou&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 217 which is for City: victoria
# http://api.openweathermap.org/data/2.5/weather?q=victoria&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 218 which is for City: udimskiy
# http://api.openweathermap.org/data/2.5/weather?q=udimskiy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 219 which is for City: labuan
# http://api.openweathermap.org/data/2.5/weather?q=labuan&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 220 which is for City: santa maria
# http://api.openweathermap.org/data/2.5/weather?q=santa maria&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 221 which is for City: faanui
# http://api.openweathermap.org/data/2.5/weather?q=faanui&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 222 which is for City: hofn
# http://api.openweathermap.org/data/2.5/weather?q=hofn&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 223 which is for City: illapel
# http://api.openweathermap.org/data/2.5/weather?q=illapel&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 224 which is for City: owando
# http://api.openweathermap.org/data/2.5/weather?q=owando&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 225 which is for City: cabedelo
# http://api.openweathermap.org/data/2.5/weather?q=cabedelo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 226 which is for City: bialogard
# http://api.openweathermap.org/data/2.5/weather?q=bialogard&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 227 which is for City: takoradi
# http://api.openweathermap.org/data/2.5/weather?q=takoradi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 228 which is for City: abnub
# http://api.openweathermap.org/data/2.5/weather?q=abnub&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 229 which is for City: tecoanapa
# http://api.openweathermap.org/data/2.5/weather?q=tecoanapa&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 230 which is for City: mildura
# http://api.openweathermap.org/data/2.5/weather?q=mildura&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 231 which is for City: nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?q=nhulunbuy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 232 which is for City: marcona
# http://api.openweathermap.org/data/2.5/weather?q=marcona&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 233 which is for City: bilibino
# http://api.openweathermap.org/data/2.5/weather?q=bilibino&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 234 which is for City: nalut
# http://api.openweathermap.org/data/2.5/weather?q=nalut&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 235 which is for City: yaritagua
# http://api.openweathermap.org/data/2.5/weather?q=yaritagua&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 236 which is for City: cardston
# http://api.openweathermap.org/data/2.5/weather?q=cardston&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 237 which is for City: cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 238 which is for City: tabuny
# http://api.openweathermap.org/data/2.5/weather?q=tabuny&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 239 which is for City: westport
# http://api.openweathermap.org/data/2.5/weather?q=westport&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 240 which is for City: owosso
# http://api.openweathermap.org/data/2.5/weather?q=owosso&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 241 which is for City: hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 242 which is for City: howard springs
# http://api.openweathermap.org/data/2.5/weather?q=howard springs&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 243 which is for City: itoman
# http://api.openweathermap.org/data/2.5/weather?q=itoman&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 244 which is for City: itarema
# http://api.openweathermap.org/data/2.5/weather?q=itarema&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 245 which is for City: pevek
# http://api.openweathermap.org/data/2.5/weather?q=pevek&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 246 which is for City: nanortalik
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 247 which is for City: sistranda
# http://api.openweathermap.org/data/2.5/weather?q=sistranda&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 248 which is for City: ponta do sol
# http://api.openweathermap.org/data/2.5/weather?q=ponta do sol&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 249 which is for City: ca mau
# http://api.openweathermap.org/data/2.5/weather?q=ca mau&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 250 which is for City: suamico
# http://api.openweathermap.org/data/2.5/weather?q=suamico&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 251 which is for City: soledade
# http://api.openweathermap.org/data/2.5/weather?q=soledade&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 252 which is for City: vestmanna
# http://api.openweathermap.org/data/2.5/weather?q=vestmanna&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 253 which is for City: carutapera
# http://api.openweathermap.org/data/2.5/weather?q=carutapera&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 254 which is for City: mpika
# http://api.openweathermap.org/data/2.5/weather?q=mpika&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 255 which is for City: san jose
# http://api.openweathermap.org/data/2.5/weather?q=san jose&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 256 which is for City: lahat
# http://api.openweathermap.org/data/2.5/weather?q=lahat&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 257 which is for City: neya
# http://api.openweathermap.org/data/2.5/weather?q=neya&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 258 which is for City: safaga
# http://api.openweathermap.org/data/2.5/weather?q=safaga&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 259 which is for City: lincoln
# http://api.openweathermap.org/data/2.5/weather?q=lincoln&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 260 which is for City: cauquenes
# http://api.openweathermap.org/data/2.5/weather?q=cauquenes&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 261 which is for City: coahuayana
# http://api.openweathermap.org/data/2.5/weather?q=coahuayana&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 262 which is for City: rawannawi
# http://api.openweathermap.org/data/2.5/weather?q=rawannawi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 263 which is for City: teguise
# http://api.openweathermap.org/data/2.5/weather?q=teguise&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 264 which is for City: solwezi
# http://api.openweathermap.org/data/2.5/weather?q=solwezi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 265 which is for City: camacha
# http://api.openweathermap.org/data/2.5/weather?q=camacha&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 266 which is for City: melfi
# http://api.openweathermap.org/data/2.5/weather?q=melfi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 267 which is for City: dinguiraye
# http://api.openweathermap.org/data/2.5/weather?q=dinguiraye&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 268 which is for City: dujuma
# http://api.openweathermap.org/data/2.5/weather?q=dujuma&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 269 which is for City: eston
# http://api.openweathermap.org/data/2.5/weather?q=eston&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 270 which is for City: los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 271 which is for City: saint anthony
# http://api.openweathermap.org/data/2.5/weather?q=saint anthony&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 272 which is for City: ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 273 which is for City: santiago
# http://api.openweathermap.org/data/2.5/weather?q=santiago&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 274 which is for City: chicama
# http://api.openweathermap.org/data/2.5/weather?q=chicama&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 275 which is for City: paita
# http://api.openweathermap.org/data/2.5/weather?q=paita&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 276 which is for City: codrington
# http://api.openweathermap.org/data/2.5/weather?q=codrington&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 277 which is for City: terney
# http://api.openweathermap.org/data/2.5/weather?q=terney&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 278 which is for City: ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 279 which is for City: tateyama
# http://api.openweathermap.org/data/2.5/weather?q=tateyama&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 280 which is for City: teya
# http://api.openweathermap.org/data/2.5/weather?q=teya&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 281 which is for City: geresk
# http://api.openweathermap.org/data/2.5/weather?q=geresk&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 282 which is for City: udachnyy
# http://api.openweathermap.org/data/2.5/weather?q=udachnyy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 283 which is for City: makarov
# http://api.openweathermap.org/data/2.5/weather?q=makarov&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 284 which is for City: sabzevar
# http://api.openweathermap.org/data/2.5/weather?q=sabzevar&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 285 which is for City: peleduy
# http://api.openweathermap.org/data/2.5/weather?q=peleduy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 286 which is for City: kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?q=kulhudhuffushi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 287 which is for City: san cristobal
# http://api.openweathermap.org/data/2.5/weather?q=san cristobal&appid=397b95f1b822905242cabd4b62006f61
# ...
# Processing request for index number: 538 which is for City: ramacca
# http://api.openweathermap.org/data/2.5/weather?q=ramacca&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 539 which is for City: kuche
# http://api.openweathermap.org/data/2.5/weather?q=kuche&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 540 which is for City: camalu
# http://api.openweathermap.org/data/2.5/weather?q=camalu&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 541 which is for City: katha
# http://api.openweathermap.org/data/2.5/weather?q=katha&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 542 which is for City: malindi
# http://api.openweathermap.org/data/2.5/weather?q=malindi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 543 which is for City: kissidougou
# http://api.openweathermap.org/data/2.5/weather?q=kissidougou&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 544 which is for City: gurupi
# http://api.openweathermap.org/data/2.5/weather?q=gurupi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 545 which is for City: novosokolniki
# http://api.openweathermap.org/data/2.5/weather?q=novosokolniki&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 546 which is for City: sao miguel do araguaia
# http://api.openweathermap.org/data/2.5/weather?q=sao miguel do araguaia&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 547 which is for City: moron
# http://api.openweathermap.org/data/2.5/weather?q=moron&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 548 which is for City: libreville
# http://api.openweathermap.org/data/2.5/weather?q=libreville&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 549 which is for City: soyo
# http://api.openweathermap.org/data/2.5/weather?q=soyo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 550 which is for City: invermere
# http://api.openweathermap.org/data/2.5/weather?q=invermere&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 551 which is for City: savelugu
# http://api.openweathermap.org/data/2.5/weather?q=savelugu&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 552 which is for City: north bend
# http://api.openweathermap.org/data/2.5/weather?q=north bend&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 553 which is for City: arrecife
# http://api.openweathermap.org/data/2.5/weather?q=arrecife&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 554 which is for City: honiara
# http://api.openweathermap.org/data/2.5/weather?q=honiara&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 555 which is for City: fuldabruck
# http://api.openweathermap.org/data/2.5/weather?q=fuldabruck&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 556 which is for City: svetlyy
# http://api.openweathermap.org/data/2.5/weather?q=svetlyy&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 557 which is for City: ligayan
# http://api.openweathermap.org/data/2.5/weather?q=ligayan&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 558 which is for City: makueni
# http://api.openweathermap.org/data/2.5/weather?q=makueni&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 559 which is for City: lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?q=lazaro cardenas&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 560 which is for City: svetogorsk
# http://api.openweathermap.org/data/2.5/weather?q=svetogorsk&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 561 which is for City: masvingo
# http://api.openweathermap.org/data/2.5/weather?q=masvingo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 562 which is for City: guerrero negro
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 563 which is for City: bauchi
# http://api.openweathermap.org/data/2.5/weather?q=bauchi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 564 which is for City: paris
# http://api.openweathermap.org/data/2.5/weather?q=paris&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 565 which is for City: tchaourou
# http://api.openweathermap.org/data/2.5/weather?q=tchaourou&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 566 which is for City: rio grande
# http://api.openweathermap.org/data/2.5/weather?q=rio grande&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 567 which is for City: alofi
# http://api.openweathermap.org/data/2.5/weather?q=alofi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 568 which is for City: preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?q=preobrazheniye&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 569 which is for City: harper
# http://api.openweathermap.org/data/2.5/weather?q=harper&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 570 which is for City: puerto escondido
# http://api.openweathermap.org/data/2.5/weather?q=puerto escondido&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 571 which is for City: malanje
# http://api.openweathermap.org/data/2.5/weather?q=malanje&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 572 which is for City: afanasyevo
# http://api.openweathermap.org/data/2.5/weather?q=afanasyevo&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 573 which is for City: lufkin
# http://api.openweathermap.org/data/2.5/weather?q=lufkin&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 574 which is for City: camana
# http://api.openweathermap.org/data/2.5/weather?q=camana&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 575 which is for City: hastings
# http://api.openweathermap.org/data/2.5/weather?q=hastings&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 576 which is for City: lazurne
# http://api.openweathermap.org/data/2.5/weather?q=lazurne&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 577 which is for City: sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 578 which is for City: gravdal
# http://api.openweathermap.org/data/2.5/weather?q=gravdal&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 579 which is for City: harwich
# http://api.openweathermap.org/data/2.5/weather?q=harwich&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 580 which is for City: ossora
# http://api.openweathermap.org/data/2.5/weather?q=ossora&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 581 which is for City: broome
# http://api.openweathermap.org/data/2.5/weather?q=broome&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 582 which is for City: shakhtinsk
# http://api.openweathermap.org/data/2.5/weather?q=shakhtinsk&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 583 which is for City: labutta
# http://api.openweathermap.org/data/2.5/weather?q=labutta&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 584 which is for City: wau
# http://api.openweathermap.org/data/2.5/weather?q=wau&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 585 which is for City: sorland
# http://api.openweathermap.org/data/2.5/weather?q=sorland&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 586 which is for City: port macquarie
# http://api.openweathermap.org/data/2.5/weather?q=port macquarie&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 587 which is for City: lewistown
# http://api.openweathermap.org/data/2.5/weather?q=lewistown&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 588 which is for City: alikalia
# http://api.openweathermap.org/data/2.5/weather?q=alikalia&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 589 which is for City: leh
# http://api.openweathermap.org/data/2.5/weather?q=leh&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 590 which is for City: manavalakurichi
# http://api.openweathermap.org/data/2.5/weather?q=manavalakurichi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 591 which is for City: tromso
# http://api.openweathermap.org/data/2.5/weather?q=tromso&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 592 which is for City: qibili
# http://api.openweathermap.org/data/2.5/weather?q=qibili&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 593 which is for City: albury
# http://api.openweathermap.org/data/2.5/weather?q=albury&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 594 which is for City: tutoia
# http://api.openweathermap.org/data/2.5/weather?q=tutoia&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 595 which is for City: chabahar
# http://api.openweathermap.org/data/2.5/weather?q=chabahar&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 596 which is for City: mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?q=mitsamiouli&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 597 which is for City: tamworth
# http://api.openweathermap.org/data/2.5/weather?q=tamworth&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 598 which is for City: barbar
# http://api.openweathermap.org/data/2.5/weather?q=barbar&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 599 which is for City: port huron
# http://api.openweathermap.org/data/2.5/weather?q=port huron&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 600 which is for City: harbour breton
# http://api.openweathermap.org/data/2.5/weather?q=harbour breton&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 601 which is for City: marystown
# http://api.openweathermap.org/data/2.5/weather?q=marystown&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 602 which is for City: clyde river
# http://api.openweathermap.org/data/2.5/weather?q=clyde river&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 603 which is for City: alyangula
# http://api.openweathermap.org/data/2.5/weather?q=alyangula&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 604 which is for City: manokwari
# http://api.openweathermap.org/data/2.5/weather?q=manokwari&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 605 which is for City: vao
# http://api.openweathermap.org/data/2.5/weather?q=vao&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 606 which is for City: nebolchi
# http://api.openweathermap.org/data/2.5/weather?q=nebolchi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 607 which is for City: hua hin
# http://api.openweathermap.org/data/2.5/weather?q=hua hin&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 608 which is for City: talara
# http://api.openweathermap.org/data/2.5/weather?q=talara&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 609 which is for City: oyama
# http://api.openweathermap.org/data/2.5/weather?q=oyama&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 610 which is for City: awjilah
# http://api.openweathermap.org/data/2.5/weather?q=awjilah&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 611 which is for City: estelle
# http://api.openweathermap.org/data/2.5/weather?q=estelle&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 612 which is for City: nelson bay
# http://api.openweathermap.org/data/2.5/weather?q=nelson bay&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 613 which is for City: babanusah
# http://api.openweathermap.org/data/2.5/weather?q=babanusah&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 614 which is for City: belaya gora
# http://api.openweathermap.org/data/2.5/weather?q=belaya gora&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 615 which is for City: kayerkan
# http://api.openweathermap.org/data/2.5/weather?q=kayerkan&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 616 which is for City: klyuchi
# http://api.openweathermap.org/data/2.5/weather?q=klyuchi&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 617 which is for City: tocopilla
# http://api.openweathermap.org/data/2.5/weather?q=tocopilla&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 618 which is for City: tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 619 which is for City: auki
# http://api.openweathermap.org/data/2.5/weather?q=auki&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 620 which is for City: amapa
# http://api.openweathermap.org/data/2.5/weather?q=amapa&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 621 which is for City: leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?q=leshukonskoye&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 622 which is for City: santa cruz
# http://api.openweathermap.org/data/2.5/weather?q=santa cruz&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 623 which is for City: berlevag
# http://api.openweathermap.org/data/2.5/weather?q=berlevag&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 624 which is for City: stromness
# http://api.openweathermap.org/data/2.5/weather?q=stromness&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 625 which is for City: launceston
# http://api.openweathermap.org/data/2.5/weather?q=launceston&appid=397b95f1b822905242cabd4b62006f61
# Processing request for index number: 626 which is for City: trelleborg
# http://api.openweathermap.org/data/2.5/weather?q=trelleborg&appid=397b95f1b822905242cabd4b62006f61
#             City Country    Lat     Lon  MaxTemp  Humidity  Cloudiness  \
# 0      jamestown      US  42.10  -79.24   48.992       100          90
# 1    piney green      US  34.72  -77.32   71.600        88           1
# 2         barrow      US  71.29 -156.79   28.400        86          90
# 3          vaini      TO -21.20 -175.20   75.200        69          75
# 4          basco      PH  20.45  121.97   80.906        87         100
# ..           ...     ...    ...     ...      ...       ...         ...
# 574   santa cruz      BO -17.80  -63.17   78.800        74          95
# 575     berlevag      NO  70.86   29.09   33.800        80          20
# 576    stromness      GB  58.97   -3.30   48.200        93         100
# 577   launceston      AU -41.45  147.17   62.006        62          90
# 578   trelleborg      SE  55.38   13.16   51.998       100          90
#
#      Windspeed
# 0     5.816044
# 1     5.816044
# 2    12.750558
# 3     9.171454
# 4    14.651957
# ..         ...
# 574   6.934514
# 575   4.697574
# 576  28.856526
# 577   5.816044
# 578   8.052984
#
# [579 rows x 8 columns]

# %%
# Access maps with unique API key
gmaps.configure(api_key=g_key)

# %%
# Store latitude and longitude in locations
locations = city_df[['Lat', 'Lon']]

# Fill NaN values and convert to float
humidity = city_df["Humidity"].astype(float)
maxhumidity = humidity.max()

# %%
# Plot Heatmap
fig = gmaps.figure()
# Create heat layer
#heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=humidity.max() ,point_radius=1)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity,dissipating=False, max_intensity=maxhumidity,point_radius=3)
# Add layer
fig.add_layer(heat_layer)
# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
idealweather_city_df = city_df.loc[(city_df["MaxTemp"] > 70) & (city_df["MaxTemp"] < 80) & (city_df["Cloudiness"] == 0), :]
ideal_city_df = idealweather_city_df.dropna(how='any')
ideal_city_df.reset_index(inplace=True)
del ideal_city_df['index']
ideal_city_df
# Out:
#                City Country    Lat     Lon  MaxTemp  Humidity  Cloudiness  \
# 0   arraial do cabo      BR -22.97  -42.03   72.212        86           0
# 1   dera ghazi khan      PK  30.06   70.63   76.136        17           0
# 2              jega      NG  12.22    4.38   79.574        44           0
# 3    porto murtinho      BR -21.70  -57.88   75.362        83           0
# 4         matamoros      MX  25.53 -103.25   74.624        37           0
# 5       broken hill      AU -31.95  141.43   78.800        22           0
# 6    cap malheureux      MU -19.98   57.61   78.008        66           0
# 7           itarema      BR  -2.92  -39.92   78.692        78           0
# 8          san jose      US  37.34 -121.89   73.004        51           0
# 9            safaga      EG  26.73   33.94   77.000        44           0
# 10       dinguiraye      GN  11.30  -10.72   72.284        78           0
# 11            mecca      SA  21.43   39.83   75.452        18           0
# 12              sur      OM  22.57   59.53   77.108        57           0
# 13         savelugu      GH   9.62   -0.83   76.280        83           0
#
#     Windspeed
# 0   19.662703
# 1    5.681828
# 2    5.234440
# 3    1.879030
# 4    8.656958
# 5   13.869028
# 6    8.992499
# 7   16.284923
# 8    2.326418
# 9    5.816044
# 10   2.236940
# 11   6.218693
# 12   4.362033
# 13   3.735690

# %%
#Finding nearest hotels 

hotels = []

for i in range(len(ideal_city_df)):
    lat = ideal_city_df.loc[i]['Lat']
    lng =  ideal_city_df.loc[i]['Lon']

    params = {
        "location": f"{lat},{lng}",
        "radius": 5000,
        "types" : "hotel",
        "key": g_key
    }
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    response = requests.get(base_url, params=params)
    nearest_hotel = response.json()
    try:
        hotels.append(nearest_hotel['results'][0]['name'])
    except:
        hotels.append("")

ideal_city_df["Hotel Name"] = hotels

ideal_city_df
# Out:
#                City Country    Lat     Lon  MaxTemp  Humidity  Cloudiness  \
# 0   arraial do cabo      BR -22.97  -42.03   72.212        86           0
# 1   dera ghazi khan      PK  30.06   70.63   76.136        17           0
# 2              jega      NG  12.22    4.38   79.574        44           0
# 3    porto murtinho      BR -21.70  -57.88   75.362        83           0
# 4         matamoros      MX  25.53 -103.25   74.624        37           0
# 5       broken hill      AU -31.95  141.43   78.800        22           0
# 6    cap malheureux      MU -19.98   57.61   78.008        66           0
# 7           itarema      BR  -2.92  -39.92   78.692        78           0
# 8          san jose      US  37.34 -121.89   73.004        51           0
# 9            safaga      EG  26.73   33.94   77.000        44           0
# 10       dinguiraye      GN  11.30  -10.72   72.284        78           0
# 11            mecca      SA  21.43   39.83   75.452        18           0
# 12              sur      OM  22.57   59.53   77.108        57           0
# 13         savelugu      GH   9.62   -0.83   76.280        83           0
#
#     Windspeed      Hotel Name
# 0   19.662703       Cabo Frio
# 1    5.681828        D G Khan
# 2    5.234440            Jega
# 3    1.879030  Porto Murtinho
# 4    8.656958       Matamoros
# 5   13.869028     Broken Hill
# 6    8.992499      Grand Baie
# 7   16.284923         Itarema
# 8    2.326418        San Jose
# 9    5.816044          Safaga
# 10   2.236940      Dinguiraye
# 11   6.218693           Mecca
# 12   4.362033             Sur
# 13   3.735690        Savelugu

# %%
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
hotel_info = [info_box_template.format(**row) for index, row in ideal_city_df.iterrows()]

# %%
#Finding hotel locations and using that to plot over the heat map
hotel_locations = ideal_city_df[['Lat','Lon']]
hotelmarkers = gmaps.marker_layer(hotel_locations,info_box_content=hotel_info)
fig.add_layer(hotelmarkers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
